# %%
# preprocess_midi.py

import os
from pathlib import Path
from typing import List, Tuple

import numpy as np
from music21 import interval, pitch

# %%
# -----------------------------
# Config
# -----------------------------
RAW_MIDI_DIR = Path("../data/mini_dataset")
PROCESSED_DIR = Path("../data/processed")
PROCESSED_DIR.mkdir(parents=True, exist_ok=True)
TRANSPOSED_DIR = PROCESSED_DIR / "transposed_midis"
TRANSPOSED_DIR.mkdir(parents=True, exist_ok=True)


# how many notes per snippet
SNIPPET_LENGTH = 32

# base rhythmic unit: 1 quarter note = 4 steps, so 1 step = sixteenth note
STEPS_PER_QUARTER = 4

# %%
# -----------------------------
# Helper functions
# -----------------------------

from music21 import converter, instrument, note, chord, stream, key, interval, pitch

def load_midi(filepath: Path) -> stream.Score:
    """Load a MIDI file into a music21 Score."""
    return converter.parse(str(filepath))


def pick_melody_part(score: stream.Score) -> stream.Part | None:
    """
    Heuristic for picking the 'melody' part:

    1. Skip *purely* percussion parts.
    2. If any part name/instrument name suggests 'melody/lead/right hand',
       pick that directly.
    3. Otherwise:
       - For each remaining part, compute:
         * n_notes
         * avg_pitch
       - Compute median avg_pitch across candidates.
       - Filter to parts with avg_pitch >= median (favor higher voices).
       - Among those, pick the one with the most notes; break ties by higher avg_pitch.

    Returns the chosen Part, or None if nothing suitable is found.
    """
    candidates = []

    for p in score.parts:
        insts = list(p.getInstruments())

        # Determine if this part is purely percussion (all instruments percussion-like)
        has_percussion = any(
            isinstance(i, instrument.UnpitchedPercussion) or
            ("percussion" in (i.bestName() or "").lower())
            for i in insts
        )
        has_non_percussion = any(
            not isinstance(i, instrument.UnpitchedPercussion) and
            "percussion" not in (i.bestName() or "").lower()
            for i in insts
        )

        # Skip only if it's *purely* percussion, not mixed
        if has_percussion and not has_non_percussion:
            continue

        # Collect notes/chords
        notes_chords = [n for n in p.recurse().notes if isinstance(n, (note.Note, chord.Chord))]
        if not notes_chords:
            continue

        # Basic stats
        pitches = []
        for n in notes_chords:
            if isinstance(n, note.Note):
                pitches.append(n.pitch.midi)
            elif isinstance(n, chord.Chord):
                pitches.append(max(nn.pitch.midi for nn in n.notes))

        if not pitches:
            continue

        n_notes = len(pitches)
        avg_pitch = sum(pitches) / len(pitches)

        # part/instrument names (lowercased)
        part_name = (p.partName or "").lower()
        inst_names = [str(inst.instrumentName or "").lower()
                      for inst in insts]

        candidates.append({
            "part": p,
            "n_notes": n_notes,
            "avg_pitch": avg_pitch,
            "part_name": part_name,
            "inst_names": inst_names,
        })

    if not candidates:
        print("  [warn] no suitable melodic parts; skipping this file.")
        return None

    # 1) Name-based shortcut: if any part name/instrument suggests "melody"
    name_keywords = [
        "melody", "lead", "right hand", "rh", "treble", "solo", "violin", "flute", "trumpet", "saw wave"
    ]

    def looks_like_melody(c):
        text = c["part_name"] + " " + " ".join(c["inst_names"])
        text = text.lower()
        return any(kw in text for kw in name_keywords)

    name_candidates = [c for c in candidates if looks_like_melody(c)]
    if name_candidates:
        # among these, pick the one with highest avg_pitch (just in case)
        best = max(name_candidates, key=lambda c: c["avg_pitch"])
        print(f"  [info] pick_melody_part: selected by name heuristic: "
              f"part_name='{best['part_name']}', avg_pitch={best['avg_pitch']:.1f}, n_notes={best['n_notes']}")
        return best["part"]

    # 2) Pitch-based filtering: keep only parts at or above median avg_pitch
    avg_pitches = [c["avg_pitch"] for c in candidates]
    median_pitch = sorted(avg_pitches)[len(avg_pitches) // 2]

    high_voice_candidates = [c for c in candidates if c["avg_pitch"] >= median_pitch]
    if not high_voice_candidates:
        high_voice_candidates = candidates  # fallback to all

    # 3) Among high-voice candidates, pick the one with the most notes & higher pitch
    best = max(
        high_voice_candidates,
        key=lambda c: (c["n_notes"], c["avg_pitch"])  # primary: many notes, secondary: higher pitch
    )

    print(
        f"  [info] pick_melody_part: selected by stats: "
        f"part_name='{best['part_name']}', avg_pitch={best['avg_pitch']:.1f}, "
        f"n_notes={best['n_notes']}"
    )

    return best["part"]




def detect_key_and_transpose(melody: stream.Part) -> stream.Part:
    """
    Detect key with music21 and transpose so tonic is C (for major) or A (for minor).
    If key detection fails for some reason, return the original melody.
    """
    try:
        key_guess = melody.analyze('key')
    except Exception as e:
        print("  [warn] key analysis failed, leaving melody untransposed:", e)
        return melody

    # Decide target tonic
    if key_guess.mode == 'major':
        target_pitch = pitch.Pitch('C')
    else:
        # treat minor keys as aiming for A minor tonic
        target_pitch = pitch.Pitch('A')

    # Build interval from current tonic to target tonic
    itvl = interval.Interval(key_guess.tonic, target_pitch)

    transposed = melody.transpose(itvl)
    return transposed


def extract_pitch_duration_sequence(melody: stream.Part) -> List[Tuple[int, float]]:
    """
    Extract (midi_pitch, quarter_length_duration) from a melody line.
    Ignore rests; collapse chords to their top note.
    """
    seq = []
    for elem in melody.recurse().notesAndRests:
        if isinstance(elem, note.Note):
            midi_pitch = elem.pitch.midi
            dur = float(elem.quarterLength)
            seq.append((midi_pitch, dur))
        elif isinstance(elem, chord.Chord):
            # take highest note in chord as melody approximation
            midi_pitch = max(n.pitch.midi for n in elem.notes)
            dur = float(elem.quarterLength)
            seq.append((midi_pitch, dur))
        else:
            # ignore rests and other stuff for now
            continue
    return seq


def convert_to_intervals_and_durations(
    pitch_dur_seq: List[Tuple[int, float]]
) -> Tuple[List[int], List[int]]:
    """
    Convert absolute pitches to pitch intervals and durations to integer steps.
    intervals[i] = pitch[i] - pitch[i-1], with first interval = 0
    durations[i] = round( quarter_length * STEPS_PER_QUARTER )
    """
    if not pitch_dur_seq:
        return [], []

    pitches = [p for (p, _) in pitch_dur_seq]
    durs_q = [d for (_, d) in pitch_dur_seq]

    intervals = [0]  # first note has no previous reference
    for i in range(1, len(pitches)):
        intervals.append(int(pitches[i] - pitches[i - 1]))

    durations = [max(1, int(round(d * STEPS_PER_QUARTER))) for d in durs_q]

    return intervals, durations


def make_snippets(
    intervals: List[int],
    durations: List[int],
    snippet_length: int = SNIPPET_LENGTH
) -> Tuple[np.ndarray, np.ndarray]:
    """
    Slice sequences into fixed-length snippets.
    We use a simple sliding window with stride = snippet_length // 2 (50% overlap).
    Short sequences yield zero snippets.
    """
    assert len(intervals) == len(durations)
    n = len(intervals)
    if n < snippet_length:
        return np.empty((0, snippet_length), dtype=np.int32), np.empty((0, snippet_length), dtype=np.int32)

    stride = snippet_length // 2
    interval_snips = []
    duration_snips = []

    for start in range(0, n - snippet_length + 1, stride):
        end = start + snippet_length
        interval_snips.append(intervals[start:end])
        duration_snips.append(durations[start:end])

    return np.array(interval_snips, dtype=np.int32), np.array(duration_snips, dtype=np.int32)

def make_snippets_with_timestamps(
    intervals: List[int],
    durations: List[int],
    durations_q: List[float],
    snippet_length: int = SNIPPET_LENGTH
) -> Tuple[np.ndarray, np.ndarray, List[Tuple[int, int]]]:
    """
    Slice sequences into fixed-length snippets.
    Also return timestamp pairs (start_q, end_q) in quarter lengths.
    """
    assert len(intervals) == len(durations)
    n = len(intervals)
    if n < snippet_length:
        return np.empty((0, snippet_length), dtype=np.int32), np.empty((0, snippet_length), dtype=np.int32), []

    stride = snippet_length // 2
    interval_snips, duration_snips, timestamps = [], [], []

    cumulative_q = np.cumsum([0] + durations_q)  # cumulative time in quarter lengths

    for start in range(0, n - snippet_length + 1, stride):
        end = start + snippet_length
        interval_snips.append(intervals[start:end])
        duration_snips.append(durations[start:end])

        start_q = cumulative_q[start]
        end_q = cumulative_q[end]
        timestamps.append((int(round(start_q)), int(round(end_q))))

    return np.array(interval_snips, dtype=np.int32), np.array(duration_snips, dtype=np.int32), timestamps

# %%
from music21 import instrument

def sanitize_melody_instrument(melody_part):
    """
    Remove any existing Instrument metadata and force a clean, non-percussion
    instrument on a non-drum channel.
    """
    # Remove ALL Instrument objects from this part
    for inst in list(melody_part.recurse().getElementsByClass(instrument.Instrument)):
        try:
            melody_part.remove(inst)
        except Exception:
            pass

    # Set a friendly part name
    melody_part.partName = "Melody"

    # Insert one clean Piano instrument at the beginning
    piano = instrument.Piano()
    piano.midiProgram = 0  # Acoustic Grand
    piano.midiChannel = 0  # Channel 1 (NOT 10/drums)
    melody_part.insert(0, piano)

    return melody_part

# %%
import warnings
from music21.midi.translate import TranslateWarning
warnings.filterwarnings("ignore", category=TranslateWarning)

# %%
# -----------------------------
# Main preprocessing
# -----------------------------
def process_all_midis(rebuild_all: bool = False):
    """
    Preprocess MIDI files into fixed-length snippets.

    Args:
        rebuild_all (bool): 
            - If False (default): 
                * Load existing snippets.npz (if present)
                * Only process NEW MIDI files not already in midi_filenames
                * Append their snippets to the existing dataset
            - If True:
                * Ignore existing snippets.npz
                * Rebuild dataset from ALL MIDI files in RAW_MIDI_DIR
    """
    out_path = PROCESSED_DIR / "snippets.npz"

    # --------------------------------------------------
    # Collect all MIDI filenames in the raw directory
    # --------------------------------------------------
    
    
    midi_files = sorted(list(RAW_MIDI_DIR.rglob("*.mid")) +
                        list(RAW_MIDI_DIR.rglob("*.midi")))

    if not midi_files:
        print(f"No MIDI files found in {RAW_MIDI_DIR}. Nothing to do.")
        return

    # We'll fill these as we go
    all_interval_snips = []
    all_duration_snips = []
    all_song_ids = []

    # These are only used if we are appending (rebuild_all=False)
    existing_intervals = None
    existing_durations = None
    existing_song_ids = None
    existing_midi_filenames = None
    existing_filenames_set = set()

    # --------------------------------------------------
    # Load existing NPZ (if present and not rebuilding)
    # --------------------------------------------------
    if not rebuild_all and out_path.exists():
        print(f"Loading existing dataset: {out_path}")
        data = np.load(out_path, allow_pickle=True)

        existing_intervals = data["intervals"]
        existing_durations = data["durations"]
        existing_song_ids = data["song_ids"]
        existing_midi_filenames = data["midi_filenames"]  # 1D array of filenames

        existing_filenames_set = set(existing_midi_filenames.tolist())

        print(f"  Existing snippets: {existing_intervals.shape[0]}")
        print(f"  Existing MIDI files: {len(existing_filenames_set)}")
    elif rebuild_all:
        print("Rebuilding dataset from scratch; ignoring existing snippets.npz (if any).")

    # --------------------------------------------------
    # Decide which files to process
    # --------------------------------------------------
    if rebuild_all or existing_midi_filenames is None:
        # process ALL files
        files_to_process = midi_files
        base_song_idx = 0
        existing_midi_filenames_list = []
    else:
        # Only process files not already in midi_filenames
        files_to_process = [p for p in midi_files if p.name not in existing_filenames_set]
        base_song_idx = len(existing_midi_filenames)
        existing_midi_filenames_list = existing_midi_filenames.tolist()

    print(f"Found {len(midi_files)} total MIDI files.")
    print(f"{len(files_to_process)} file(s) to process this run.")

    if not files_to_process:
        print("No new MIDI files found. Dataset unchanged.")
        return

    # We'll also build up the new filenames in order
    new_filenames_list = []

    # --------------------------------------------------
    # Process selected MIDI files
    # --------------------------------------------------
    for local_idx, midi_path in enumerate(files_to_process):
        # song_id for this file within the full dataset:
        # existing songs first, then new ones in order
        song_id = base_song_idx + local_idx

        print(f"Processing {midi_path.name} "
              f"({local_idx + 1}/{len(files_to_process)}), assigned song_id={song_id}")

        try:
            score = load_midi(midi_path)
        except Exception as e:
            print(f"  Failed to load {midi_path.name}: {e}")
            continue

        melody = pick_melody_part(score)
        if melody is None:
            print(f"  Skipping {midi_path.name}: no usable melodic part found.")
            continue
        melody = detect_key_and_transpose(melody)
        melody = sanitize_melody_instrument(melody)

        # Save transposed melody
        out_midi_path = TRANSPOSED_DIR / f"transposed_{midi_path.stem}.mid"
        try:
            melody.write("midi", fp=str(out_midi_path))
            print(f"  Saved transposed: {out_midi_path}")
        except Exception as e:
            print(f"  [warn] could not save transposed MIDI for {midi_path.name}: {e}")

        pitch_dur_seq = extract_pitch_duration_sequence(melody)

        if len(pitch_dur_seq) < SNIPPET_LENGTH:
            print(f"  Skipping {midi_path.name}: too few notes ({len(pitch_dur_seq)})")
            continue

        intervals, durations = convert_to_intervals_and_durations(pitch_dur_seq)

        i_snips, d_snips = make_snippets(intervals, durations, SNIPPET_LENGTH)

        # durs_q = [d for (_, d) in pitch_dur_seq]
        # i_snips, d_snips, timestamp_pairs = make_snippets_with_timestamps(intervals, durations, durs_q, SNIPPET_LENGTH)

        # genre = midi_path.parent.name.lower()  # extract genre from folder

        if i_snips.shape[0] == 0:
            print(f"  No snippets extracted from {midi_path.name}")
            continue

        all_interval_snips.append(i_snips)
        all_duration_snips.append(d_snips)
        all_song_ids.append(np.full(i_snips.shape[0], song_id, dtype=np.int32))

        new_filenames_list.append(midi_path.name)

    # --------------------------------------------------
    # If nothing new was processed successfully
    # --------------------------------------------------
    if not all_interval_snips:
        print("No snippets extracted from selected MIDI files. Dataset unchanged.")
        return

    # Stack new snippets
    new_intervals = np.vstack(all_interval_snips)
    new_durations = np.vstack(all_duration_snips)
    new_song_ids = np.concatenate(all_song_ids)

    # --------------------------------------------------
    # Merge old + new or just use new (if rebuild_all or no existing)
    # --------------------------------------------------
    if not rebuild_all and existing_intervals is not None:
        intervals_arr = np.vstack([existing_intervals, new_intervals])
        durations_arr = np.vstack([existing_durations, new_durations])
        song_ids_arr = np.concatenate([existing_song_ids, new_song_ids])

        # Append new filenames after existing, in consistent order
        midi_filenames_arr = np.array(existing_midi_filenames_list + new_filenames_list)
    else:
        intervals_arr = new_intervals
        durations_arr = new_durations
        song_ids_arr = new_song_ids

        # When rebuilding, our song_ids are aligned with files_to_process in order
        # but we still want the full midi_files list in case some were skipped.
        midi_filenames_arr = np.array(new_filenames_list)

    # --------------------------------------------------
    # Save updated dataset
    # --------------------------------------------------
    np.savez_compressed(
        out_path,
        intervals=intervals_arr,
        durations=durations_arr,
        song_ids=song_ids_arr,
        midi_filenames=midi_filenames_arr,
    )

    print(f"Saved updated snippets to {out_path}")
    print(f"Total snippets: {intervals_arr.shape[0]}")
    print(f"Total MIDI files represented: {len(midi_filenames_arr)}")

# %% [markdown]
# process_all_midis(rebuild_all=True)

# %%
# -----------------------------
# Main preprocessing
# -----------------------------
def process_all_midis_new(rebuild_all: bool = False):
    """
    Preprocess MIDI files into fixed-length snippets.

    Args:
        rebuild_all (bool): 
            - If False (default): 
                * Load existing snippets.npz (if present)
                * Only process NEW MIDI files not already in midi_filenames
                * Append their snippets to the existing dataset
            - If True:
                * Ignore existing snippets.npz
                * Rebuild dataset from ALL MIDI files in RAW_MIDI_DIR
    """
    out_path = PROCESSED_DIR / "snippets.npz"

    # --------------------------------------------------
    # Collect all MIDI filenames in the raw directory
    # --------------------------------------------------
    midi_files = sorted(list(RAW_MIDI_DIR.rglob("*.mid")) +
                        list(RAW_MIDI_DIR.rglob("*.midi")))

    if not midi_files:
        print(f"No MIDI files found in {RAW_MIDI_DIR}. Nothing to do.")
        return

    # We'll fill these as we go
    all_interval_snips = []
    all_duration_snips = []
    all_song_ids = []
    all_genre_snips = []  # <-- per-snippet genres

    # These are only used if we are appending (rebuild_all=False)
    existing_intervals = None
    existing_durations = None
    existing_song_ids = None
    existing_midi_filenames = None
    existing_genres = None  # <-- existing genres (if any)
    existing_filenames_set = set()

    # --------------------------------------------------
    # Load existing NPZ (if present and not rebuilding)
    # --------------------------------------------------
    if not rebuild_all and out_path.exists():
        print(f"Loading existing dataset: {out_path}")
        data = np.load(out_path, allow_pickle=True)

        existing_intervals = data["intervals"]
        existing_durations = data["durations"]
        existing_song_ids = data["song_ids"]
        existing_midi_filenames = data["midi_filenames"]  # 1D array of filenames

        # If an older npz didn't have genres, we'll synthesize "unknown"
        if "genres" in data.files:
            existing_genres = data["genres"]
        else:
            existing_genres = np.array(
                ["unknown"] * existing_intervals.shape[0],
                dtype=object
            )

        existing_filenames_set = set(existing_midi_filenames.tolist())

        print(f"  Existing snippets: {existing_intervals.shape[0]}")
        print(f"  Existing MIDI files: {len(existing_filenames_set)}")
    elif rebuild_all:
        print("Rebuilding dataset from scratch; ignoring existing snippets.npz (if any).")

    # --------------------------------------------------
    # Decide which files to process
    # --------------------------------------------------
    if rebuild_all or existing_midi_filenames is None:
        # process ALL files
        files_to_process = midi_files
        base_song_idx = 0
        existing_midi_filenames_list = []
    else:
        # Only process files not already in midi_filenames
        files_to_process = [p for p in midi_files if p.name not in existing_filenames_set]
        base_song_idx = len(existing_midi_filenames)
        existing_midi_filenames_list = existing_midi_filenames.tolist()

    print(f"Found {len(midi_files)} total MIDI files.")
    print(f"{len(files_to_process)} file(s) to process this run.")

    if not files_to_process:
        print("No new MIDI files found. Dataset unchanged.")
        return

    # We'll also build up the new filenames in order
    new_filenames_list = []

    # --------------------------------------------------
    # Process selected MIDI files
    # --------------------------------------------------
    for local_idx, midi_path in enumerate(files_to_process):
        # song_id for this file within the full dataset:
        # existing songs first, then new ones in order
        song_id = base_song_idx + local_idx

        print(f"Processing {midi_path.name} "
              f"({local_idx + 1}/{len(files_to_process)}), assigned song_id={song_id}")

        try:
            score = load_midi(midi_path)
        except Exception as e:
            print(f"  Failed to load {midi_path.name}: {e}")
            continue

        melody = pick_melody_part(score)
        if melody is None:
            print(f"  Skipping {midi_path.name}: no usable melodic part found.")
            continue
        melody = detect_key_and_transpose(melody)
        melody = sanitize_melody_instrument(melody)

        # Save transposed melody
        out_midi_path = TRANSPOSED_DIR / f"transposed_{midi_path.stem}.mid"
        try:
            melody.write("midi", fp=str(out_midi_path))
            print(f"  Saved transposed: {out_midi_path}")
        except Exception as e:
            print(f"  [warn] could not save transposed MIDI for {midi_path.name}: {e}")

        pitch_dur_seq = extract_pitch_duration_sequence(melody)

        if len(pitch_dur_seq) < SNIPPET_LENGTH:
            print(f"  Skipping {midi_path.name}: too few notes ({len(pitch_dur_seq)})")
            continue

        intervals, durations = convert_to_intervals_and_durations(pitch_dur_seq)

        i_snips, d_snips = make_snippets(intervals, durations, SNIPPET_LENGTH)

        if i_snips.shape[0] == 0:
            print(f"  No snippets extracted from {midi_path.name}")
            continue

        # --- Genre per snippet (from folder name) ---
        genre = midi_path.parent.name.lower()
        num_snips = i_snips.shape[0]
        all_genre_snips.append(np.array([genre] * num_snips, dtype=object))

        all_interval_snips.append(i_snips)
        all_duration_snips.append(d_snips)
        all_song_ids.append(np.full(num_snips, song_id, dtype=np.int32))

        new_filenames_list.append(midi_path.name)

    # --------------------------------------------------
    # If nothing new was processed successfully
    # --------------------------------------------------
    if not all_interval_snips:
        print("No snippets extracted from selected MIDI files. Dataset unchanged.")
        return

    # Stack new snippets
    new_intervals = np.vstack(all_interval_snips)
    new_durations = np.vstack(all_duration_snips)
    new_song_ids = np.concatenate(all_song_ids)
    new_genres = np.concatenate(all_genre_snips)  # <-- all new snippet genres

    # --------------------------------------------------
    # Merge old + new or just use new (if rebuild_all or no existing)
    # --------------------------------------------------
    if not rebuild_all and existing_intervals is not None:
        intervals_arr = np.vstack([existing_intervals, new_intervals])
        durations_arr = np.vstack([existing_durations, new_durations])
        song_ids_arr = np.concatenate([existing_song_ids, new_song_ids])

        # Merge genres (old + new)
        genres_arr = np.concatenate([existing_genres, new_genres])

        # Append new filenames after existing, in consistent order
        midi_filenames_arr = np.array(existing_midi_filenames_list + new_filenames_list)
    else:
        intervals_arr = new_intervals
        durations_arr = new_durations
        song_ids_arr = new_song_ids
        genres_arr = new_genres  # only new
        midi_filenames_arr = np.array(new_filenames_list)

    # --------------------------------------------------
    # Save updated dataset (with genres)
    # --------------------------------------------------
    np.savez_compressed(
        out_path,
        intervals=intervals_arr,
        durations=durations_arr,
        song_ids=song_ids_arr,
        midi_filenames=midi_filenames_arr,
        genres=genres_arr,  # <-- new field
    )

    print(f"Saved updated snippets to {out_path}")
    print(f"Total snippets: {intervals_arr.shape[0]}")
    print(f"Total MIDI files represented: {len(midi_filenames_arr)}")

# %% [markdown]
# process_all_midis_new(rebuild_all = True)

# %%
def process_all_midis_new_with_sec(rebuild_all: bool = False, counts: int = -1):
    """
    Preprocess MIDI files into fixed-length snippets.

    This version:
      - Uses original melody's quarter-length timing (musical time).
      - For each snippet, stores:
          * genre
          * snippet_start_idx, snippet_end_idx (note indices in melody)
          * snippet_start_qs, snippet_end_qs (cumulative quarter lengths)
          * snippet_start_secs, snippet_end_secs (seconds scaled to real song length)
          * human-readable snippet_labels:
              "<genre>_<stem>_idx000016_to000048_t0012.34s_to0020.56s"
      - Writes everything into one snippets.npz.
      - Can append to existing dataset (unless rebuild_all=True).
      - Can limit files processed via `counts`.
    """

    out_path = PROCESSED_DIR / "snippets.npz"

    # --------------------------------------------------
    # Collect MIDI files
    # --------------------------------------------------
    midi_files = sorted(
        list(RAW_MIDI_DIR.rglob("*.mid")) +
        list(RAW_MIDI_DIR.rglob("*.midi"))
    )

    if not midi_files:
        print("No MIDI files found.")
        return

    # Per-snippet accumulators
    all_interval_snips = []
    all_duration_snips = []
    all_song_ids = []
    all_genres = []
    all_snippet_labels = []
    all_start_indices = []
    all_end_indices = []
    all_start_qs = []
    all_end_qs = []
    all_start_secs = []
    all_end_secs = []

    # Existing data (for appending)
    existing_intervals = None
    existing_durations = None
    existing_song_ids = None
    existing_midi_filenames = None
    existing_genres = None
    existing_snippet_labels = None
    existing_start_indices = None
    existing_end_indices = None
    existing_start_qs = None
    existing_end_qs = None
    existing_start_secs = None
    existing_end_secs = None
    existing_filenames_set = set()

    # --------------------------------------------------
    # Load existing dataset if present
    # --------------------------------------------------
    if not rebuild_all and out_path.exists():
        print(f"Loading existing dataset from {out_path}")
        data = np.load(out_path, allow_pickle=True)

        existing_intervals = data["intervals"]
        existing_durations = data["durations"]
        existing_song_ids = data["song_ids"]
        existing_midi_filenames = data["midi_filenames"]

        existing_genres = data["genres"] if "genres" in data.files else None
        existing_snippet_labels = data["snippet_labels"] if "snippet_labels" in data.files else None

        existing_start_indices = data["snippet_start_indices"] if "snippet_start_indices" in data.files else None
        existing_end_indices = data["snippet_end_indices"] if "snippet_end_indices" in data.files else None
        existing_start_qs = data["snippet_start_qs"] if "snippet_start_qs" in data.files else None
        existing_end_qs = data["snippet_end_qs"] if "snippet_end_qs" in data.files else None
        existing_start_secs = data["snippet_start_secs"] if "snippet_start_secs" in data.files else None
        existing_end_secs = data["snippet_end_secs"] if "snippet_end_secs" in data.files else None

        existing_filenames_set = set(existing_midi_filenames.tolist())

        print(f"  Existing snippets: {existing_intervals.shape[0]}")
        print(f"  Existing MIDI songs: {len(existing_filenames_set)}")

    elif rebuild_all:
        print("Rebuilding dataset from scratch (ignoring existing snippets.npz).")

    # --------------------------------------------------
    # Decide which files to process
    # --------------------------------------------------
    if rebuild_all or existing_midi_filenames is None:
        files_to_process = midi_files
        base_song_idx = 0
        existing_filename_list = []
    else:
        files_to_process = [p for p in midi_files if p.name not in existing_filenames_set]
        base_song_idx = len(existing_midi_filenames)
        existing_filename_list = existing_midi_filenames.tolist()

    print(f"Found {len(midi_files)} total MIDI files.")
    print(f"{len(files_to_process)} new file(s) before limiting by counts.")

    if counts == -1:
        print(f"Processing all {len(files_to_process)} file(s)")
    elif counts > 0:
        files_to_process = files_to_process[:counts]
        print(f"Processing only first {len(files_to_process)} file(s) due to counts={counts}.")
    else:
        print("counts <= 0 → no processing performed.")
        return

    new_midi_filenames_list = []

    # ---------------------------------------------------------
    # Helper: extract original pitch + duration_q from melody
    # ---------------------------------------------------------
    def extract_pitch_dur_from_melody(melody_part):
        """
        Returns:
            pitches:  list[int]    (MIDI numbers)
            durs_q:   list[float]  (quarterLength)
        This is purely in musical time.
        """
        pitches = []
        durs_q = []
        for elem in melody_part.recurse().notesAndRests:
            if isinstance(elem, note.Rest):
                continue
            if isinstance(elem, note.Note):
                midi_pitch = elem.pitch.midi
                dur_q = float(elem.quarterLength)
                pitches.append(midi_pitch)
                durs_q.append(dur_q)
            elif isinstance(elem, chord.Chord):
                midi_pitch = max(n.pitch.midi for n in elem.notes)
                dur_q = float(elem.quarterLength)
                pitches.append(midi_pitch)
                durs_q.append(dur_q)
        return pitches, durs_q

    # ---------------------------------------------------------
    # Helper: make snippets + musical timing info
    # ---------------------------------------------------------
    def make_snippets_with_musical_time(intervals, durations_steps, original_durs_q, snippet_length=SNIPPET_LENGTH):
        """
        intervals:         list[int]         (pitch intervals)
        durations_steps:   list[int]         (quantized duration steps)
        original_durs_q:   list[float]       (original quarter-length durations, same indexing)
        Returns:
            interval_snips: (num_snips, L)
            duration_snips: (num_snips, L)
            start_indices:  (num_snips,)
            end_indices:    (num_snips,)
            start_qs:       (num_snips,)
            end_qs:         (num_snips,)
        """
        n = len(intervals)
        if n < snippet_length:
            return (np.empty((0, snippet_length), dtype=np.int32),
                    np.empty((0, snippet_length), dtype=np.int32),
                    np.empty((0,), dtype=np.int32),
                    np.empty((0,), dtype=np.int32),
                    np.empty((0,), dtype=float),
                    np.empty((0,), dtype=float))

        stride = snippet_length // 2

        # cumulative quarter lengths for original melody
        cum_q = np.cumsum([0.0] + list(original_durs_q))  # length n+1

        interval_snips = []
        duration_snips = []
        start_indices = []
        end_indices = []
        start_qs = []
        end_qs = []

        for start in range(0, n - snippet_length + 1, stride):
            end = start + snippet_length

            interval_snips.append(intervals[start:end])
            duration_snips.append(durations_steps[start:end])

            start_indices.append(start)
            end_indices.append(end)

            start_qs.append(cum_q[start])
            end_qs.append(cum_q[end])

        return (np.array(interval_snips, dtype=np.int32),
                np.array(duration_snips, dtype=np.int32),
                np.array(start_indices, dtype=np.int32),
                np.array(end_indices, dtype=np.int32),
                np.array(start_qs, dtype=float),
                np.array(end_qs, dtype=float))

    # ===========================================
    # PROCESS EACH FILE
    # ===========================================
    for file_idx, midi_path in enumerate(files_to_process):
        song_id = base_song_idx + file_idx
        genre = midi_path.parent.name.lower()

        print(f"\nProcessing {midi_path.name} ({file_idx + 1}/{len(files_to_process)}), genre={genre}")

        # Load score
        try:
            score = load_midi(midi_path)
        except Exception as e:
            print(f"  [error] failed to load {midi_path.name}: {e}")
            continue

        melody = pick_melody_part(score)
        if melody is None:
            print("  [warn] no melody part found; skipping.")
            continue

        # ---- Extract original (pitch, duration_q) in musical time ----
        pitches_orig, durs_orig_q = extract_pitch_dur_from_melody(melody)
        print(f"    [debug] original melodic events = {len(pitches_orig)}")

        if len(pitches_orig) < SNIPPET_LENGTH:
            print("  Skipping: too few melodic events.")
            continue

        # ---- Transpose + sanitize for saving / normalization ----
        melody_transposed = detect_key_and_transpose(melody)
        melody_transposed = sanitize_melody_instrument(melody_transposed)

        out_midi_path = TRANSPOSED_DIR / f"transposed_{midi_path.stem}.mid"
        try:
            melody_transposed.write("midi", fp=str(out_midi_path))
            print(f"  Saved transposed: {out_midi_path}")
        except Exception as e:
            print(f"  [warn] could not save transposed MIDI for {midi_path.name}: {e}")

        # ---- Convert to intervals + integer duration steps (model input) ----
        pitch_dur_seq = list(zip(pitches_orig, durs_orig_q))
        intervals, durations_steps = convert_to_intervals_and_durations(pitch_dur_seq)

        # ---- Make snippets with musical timing info ----
        (i_snips, d_snips,
         start_indices, end_indices,
         start_qs, end_qs) = make_snippets_with_musical_time(
            intervals, durations_steps, durs_orig_q
        )

        if i_snips.shape[0] == 0:
            print("  [info] No snippets extracted after slicing.")
            continue

        # ---- Approximate seconds from quarter lengths, scaled to real song length ----

        # 1) total melodic quarter length (from our cumulative Q values)
        total_q_melody = float(end_qs.max()) if end_qs.size > 0 else 0.0

        # 2) total song duration in seconds from score.secondsMap
        sm = score.secondsMap if not callable(score.secondsMap) else score.secondsMap()
        total_secs = 0.0
        for item in sm:
            off = float(item.get("offsetSeconds", 0.0))
            end_t = float(item.get("endTimeSeconds", off))
            if end_t > total_secs:
                total_secs = end_t

        # 3) derive effective sec-per-quarter so that melody span maps into real song length
        if total_q_melody > 0 and total_secs > 0:
            sec_per_q_eff = total_secs / total_q_melody
        else:
            # fallback if something weird happens
            tempos = score.flatten().getElementsByClass("MetronomeMark")
            if tempos:
                bpm = tempos[0].number
                if bpm and bpm > 0:
                    sec_per_q_eff = 60.0 / bpm
                else:
                    sec_per_q_eff = 0.5
            else:
                sec_per_q_eff = 0.5  # default 120 bpm

        start_secs = start_qs * sec_per_q_eff
        end_secs = end_qs * sec_per_q_eff

        # ---- Build labels (NO q ranges, WITH seconds) ----
        labels = []
        for s_idx, e_idx, ss, es in zip(start_indices, end_indices, start_secs, end_secs):
            label = (
                f"{genre}_{midi_path.stem}_"
                f"idx{s_idx:06d}_to{e_idx:06d}_"
                f"t{ss:07.2f}s_to{es:07.2f}s"
            )
            labels.append(label)

        # ---- Accumulate per-snippet arrays ----
        num_snips = i_snips.shape[0]
        all_interval_snips.append(i_snips)
        all_duration_snips.append(d_snips)
        all_song_ids.append(np.full(num_snips, song_id, dtype=np.int32))
        all_genres.append(np.array([genre] * num_snips, dtype=object))
        all_snippet_labels.append(np.array(labels, dtype=object))
        all_start_indices.append(start_indices)
        all_end_indices.append(end_indices)
        all_start_qs.append(start_qs)
        all_end_qs.append(end_qs)
        all_start_secs.append(start_secs)
        all_end_secs.append(end_secs)

        new_midi_filenames_list.append(midi_path.name)

    # ================================
    # MERGE + SAVE
    # ================================
    if not all_interval_snips:
        print("No snippets extracted from selected MIDI files. Dataset unchanged.")
        return

    new_intervals = np.vstack(all_interval_snips)
    new_durations = np.vstack(all_duration_snips)
    new_ids = np.concatenate(all_song_ids)
    new_genres = np.concatenate(all_genres)
    new_labels = np.concatenate(all_snippet_labels)
    new_start_indices = np.concatenate(all_start_indices)
    new_end_indices = np.concatenate(all_end_indices)
    new_start_qs = np.concatenate(all_start_qs)
    new_end_qs = np.concatenate(all_end_qs)
    new_start_secs = np.concatenate(all_start_secs)
    new_end_secs = np.concatenate(all_end_secs)

    if existing_intervals is not None and not rebuild_all:
        intervals_arr = np.vstack([existing_intervals, new_intervals])
        durations_arr = np.vstack([existing_durations, new_durations])
        song_ids_arr = np.concatenate([existing_song_ids, new_ids])

        if existing_genres is not None:
            genres_arr = np.concatenate([existing_genres, new_genres])
        else:
            genres_arr = np.concatenate(
                [np.array(["unknown"] * existing_intervals.shape[0], dtype=object), new_genres]
            )

        if existing_snippet_labels is not None:
            labels_arr = np.concatenate([existing_snippet_labels, new_labels])
        else:
            labels_arr = new_labels

        if existing_start_indices is not None:
            start_idx_arr = np.concatenate([existing_start_indices, new_start_indices])
        else:
            start_idx_arr = new_start_indices

        if existing_end_indices is not None:
            end_idx_arr = np.concatenate([existing_end_indices, new_end_indices])
        else:
            end_idx_arr = new_end_indices

        if existing_start_qs is not None:
            start_q_arr = np.concatenate([existing_start_qs, new_start_qs])
        else:
            start_q_arr = new_start_qs

        if existing_end_qs is not None:
            end_q_arr = np.concatenate([existing_end_qs, new_end_qs])
        else:
            end_q_arr = new_end_qs

        if existing_start_secs is not None:
            start_sec_arr = np.concatenate([existing_start_secs, new_start_secs])
        else:
            start_sec_arr = new_start_secs

        if existing_end_secs is not None:
            end_sec_arr = np.concatenate([existing_end_secs, new_end_secs])
        else:
            end_sec_arr = new_end_secs

        midi_filenames_arr = np.array(existing_filename_list + new_midi_filenames_list)

    else:
        intervals_arr = new_intervals
        durations_arr = new_durations
        song_ids_arr = new_ids
        genres_arr = new_genres
        labels_arr = new_labels
        start_idx_arr = new_start_indices
        end_idx_arr = new_end_indices
        start_q_arr = new_start_qs
        end_q_arr = new_end_qs
        start_sec_arr = new_start_secs
        end_sec_arr = new_end_secs
        midi_filenames_arr = np.array(new_midi_filenames_list)

    # Save final dataset
    np.savez_compressed(
        out_path,
        intervals=intervals_arr,
        durations=durations_arr,
        song_ids=song_ids_arr,
        midi_filenames=midi_filenames_arr,
        genres=genres_arr,
        snippet_labels=labels_arr,
        snippet_start_indices=start_idx_arr,
        snippet_end_indices=end_idx_arr,
        snippet_start_qs=start_q_arr,
        snippet_end_qs=end_q_arr,
        snippet_start_secs=start_sec_arr,
        snippet_end_secs=end_sec_arr,
    )

    print("\n✅ Saved final dataset:", out_path)
    print("Total snippets:", intervals_arr.shape[0])
    print("Total songs:", len(midi_filenames_arr))

# %% [markdown]
# process_all_midis_new_with_sec(rebuild_all = True, counts=-1)

# %%
from concurrent.futures import ProcessPoolExecutor
from pathlib import Path

def _process_single_midi_for_sec(args):
    """
    Worker function for parallel processing.
    Args is a tuple: (midi_path_str, snippet_length)

    Returns a dict of arrays for this MIDI, or None if skipped.
    NOTE: This function does NOT assign song_ids. That is done centrally
    in the main process after collecting all successful results.
    """
    midi_path_str, snippet_length = args
    midi_path = Path(midi_path_str)

    try:
        score = load_midi(midi_path)
    except Exception as e:
        print(f"  [worker] failed to load {midi_path.name}: {e}")
        return None

    melody = pick_melody_part(score)
    if melody is None:
        print(f"  [worker] no melody part in {midi_path.name}; skipping.")
        return None

    # ---- Extract original (pitch, duration_q) in musical time ----
    pitches_orig = []
    durs_orig_q = []
    for elem in melody.recurse().notesAndRests:
        if isinstance(elem, note.Rest):
            continue
        if isinstance(elem, note.Note):
            midi_pitch = elem.pitch.midi
            dur_q = float(elem.quarterLength)
        elif isinstance(elem, chord.Chord):
            midi_pitch = max(n.pitch.midi for n in elem.notes)
            dur_q = float(elem.quarterLength)
        else:
            continue
        pitches_orig.append(midi_pitch)
        durs_orig_q.append(dur_q)

    if len(pitches_orig) < snippet_length:
        print(f"  [worker] {midi_path.name}: too few melodic events ({len(pitches_orig)}).")
        return None

    # ---- Transpose + sanitize and save transposed melody (optional but kept) ----
    melody_transposed = detect_key_and_transpose(melody)
    melody_transposed = sanitize_melody_instrument(melody_transposed)

    out_midi_path = TRANSPOSED_DIR / f"transposed_{midi_path.stem}.mid"
    try:
        melody_transposed.write("midi", fp=str(out_midi_path))
        print(f"  [worker] Saved transposed: {out_midi_path}")
    except Exception as e:
        print(f"  [worker] could not save transposed MIDI for {midi_path.name}: {e}")

    # ---- Convert to intervals + integer duration steps (model input) ----
    pitch_dur_seq = list(zip(pitches_orig, durs_orig_q))
    intervals, durations_steps = convert_to_intervals_and_durations(pitch_dur_seq)

    # ---- Make snippets with musical timing info ----
    n = len(intervals)
    stride = snippet_length // 2
    cum_q = np.cumsum([0.0] + list(durs_orig_q))

    interval_snips = []
    duration_snips = []
    start_indices = []
    end_indices = []
    start_qs = []
    end_qs = []

    for start in range(0, n - snippet_length + 1, stride):
        end = start + snippet_length
        interval_snips.append(intervals[start:end])
        duration_snips.append(durations_steps[start:end])
        start_indices.append(start)
        end_indices.append(end)
        start_qs.append(cum_q[start])
        end_qs.append(cum_q[end])

    if not interval_snips:
        print(f"  [worker] {midi_path.name}: no snippets after slicing.")
        return None

    interval_snips = np.array(interval_snips, dtype=np.int32)
    duration_snips = np.array(duration_snips, dtype=np.int32)
    start_indices = np.array(start_indices, dtype=np.int32)
    end_indices = np.array(end_indices, dtype=np.int32)
    start_qs = np.array(start_qs, dtype=float)
    end_qs = np.array(end_qs, dtype=float)

    # ---- Approximate seconds from quarter lengths, scaled to real song length ----
    total_q_melody = float(end_qs.max()) if end_qs.size > 0 else 0.0

    sm = score.secondsMap if not callable(score.secondsMap) else score.secondsMap()
    total_secs = 0.0
    for item in sm:
        off = float(item.get("offsetSeconds", 0.0))
        end_t = float(item.get("endTimeSeconds", off))
        if end_t > total_secs:
            total_secs = end_t

    if total_q_melody > 0 and total_secs > 0:
        sec_per_q_eff = total_secs / total_q_melody
    else:
        tempos = score.flatten().getElementsByClass("MetronomeMark")
        if tempos:
            bpm = tempos[0].number
            if bpm and bpm > 0:
                sec_per_q_eff = 60.0 / bpm
            else:
                sec_per_q_eff = 0.5
        else:
            sec_per_q_eff = 0.5

    start_secs = start_qs * sec_per_q_eff
    end_secs = end_qs * sec_per_q_eff

    # ---- Genre & labels ----
    genre = midi_path.parent.name.lower()
    labels = [
        f"{genre}_{midi_path.stem}_idx{s_idx:06d}_to{e_idx:06d}_t{ss:07.2f}s_to{es:07.2f}s"
        for s_idx, e_idx, ss, es in zip(start_indices, end_indices, start_secs, end_secs)
    ]
    genres_arr = np.array([genre] * interval_snips.shape[0], dtype=object)
    labels_arr = np.array(labels, dtype=object)

    return {
        "intervals": interval_snips,
        "durations": duration_snips,
        "genres": genres_arr,
        "labels": labels_arr,
        "start_indices": start_indices,
        "end_indices": end_indices,
        "start_qs": start_qs,
        "end_qs": end_qs,
        "start_secs": start_secs,
        "end_secs": end_secs,
        "filename": midi_path.name,
    }

# %%
def process_all_midis_new_with_sec_parallel(
    rebuild_all: bool = False, counts: int = -1, num_workers: int = 4
):
    """
    Parallel version of process_all_midis_new_with_sec with FIXED song_id ↔ filename alignment.

    - Worker does NOT assign song_ids.
    - Main process enumerates successful results and assigns song_ids
      sequentially, so song_id == index into midi_filenames.
    """

    out_path = PROCESSED_DIR / "snippets.npz"

    # --------------------------------------------------
    # Collect MIDI files
    # --------------------------------------------------
    midi_files = sorted(
        list(RAW_MIDI_DIR.rglob("*.mid")) +
        list(RAW_MIDI_DIR.rglob("*.midi"))
    )

    if not midi_files:
        print("No MIDI files found.")
        return

    # Per-snippet accumulators
    all_interval_snips = []
    all_duration_snips = []
    all_song_ids = []
    all_genres = []
    all_snippet_labels = []
    all_start_indices = []
    all_end_indices = []
    all_start_qs = []
    all_end_qs = []
    all_start_secs = []
    all_end_secs = []

    # Existing data (for appending)
    existing_intervals = None
    existing_durations = None
    existing_song_ids = None
    existing_midi_filenames = None
    existing_genres = None
    existing_snippet_labels = None
    existing_start_indices = None
    existing_end_indices = None
    existing_start_qs = None
    existing_end_qs = None
    existing_start_secs = None
    existing_end_secs = None
    existing_filenames_set = set()

    # --------------------------------------------------
    # Load existing dataset if present
    # --------------------------------------------------
    if not rebuild_all and out_path.exists():
        print(f"Loading existing dataset from {out_path}")
        data = np.load(out_path, allow_pickle=True)

        existing_intervals = data["intervals"]
        existing_durations = data["durations"]
        existing_song_ids = data["song_ids"]
        existing_midi_filenames = data["midi_filenames"]

        existing_genres = data.get("genres", None)
        existing_snippet_labels = data.get("snippet_labels", None)
        existing_start_indices = data.get("snippet_start_indices", None)
        existing_end_indices = data.get("snippet_end_indices", None)
        existing_start_qs = data.get("snippet_start_qs", None)
        existing_end_qs = data.get("snippet_end_qs", None)
        existing_start_secs = data.get("snippet_start_secs", None)
        existing_end_secs = data.get("snippet_end_secs", None)

        existing_filenames_set = set(existing_midi_filenames.tolist())

        print(f"  Existing snippets: {existing_intervals.shape[0]}")
        print(f"  Existing MIDI songs: {len(existing_filenames_set)}")

    elif rebuild_all:
        print("Rebuilding dataset from scratch (ignoring existing snippets.npz).")

    # --------------------------------------------------
    # Decide which files to process
    # --------------------------------------------------
    if rebuild_all or existing_midi_filenames is None:
        files_to_process = midi_files
        base_song_idx = 0
        existing_filename_list = []
    else:
        files_to_process = [p for p in midi_files if p.name not in existing_filenames_set]
        base_song_idx = len(existing_midi_filenames)
        existing_filename_list = existing_midi_filenames.tolist()

    print(f"Found {len(midi_files)} total MIDI files.")
    print(f"{len(files_to_process)} new file(s) before limiting by counts.")

    if counts == -1:
        print(f"Processing all {len(files_to_process)} file(s)")
    elif counts > 0:
        files_to_process = files_to_process[:counts]
        print(f"Processing only first {len(files_to_process)} file(s) due to counts={counts}.")
    else:
        print("counts <= 0 → no processing performed.")
        return

    # --------------------------------------------------
    # PARALLEL PROCESSING
    # --------------------------------------------------
    worker_args = [
        (str(midi_path), SNIPPET_LENGTH)
        for midi_path in files_to_process
    ]

    print(f"Using {num_workers} worker process(es).")

    with ProcessPoolExecutor(max_workers=num_workers) as executor:
        results = list(executor.map(_process_single_midi_for_sec, worker_args))

    # Filter to only successful results (non-None)
    valid_results = [res for res in results if res is not None]

    new_midi_filenames_list = []
    # Assign song_ids sequentially starting from base_song_idx
    for local_song_idx, res in enumerate(valid_results):
        song_id = base_song_idx + local_song_idx
        n_snips = res["intervals"].shape[0]

        all_interval_snips.append(res["intervals"])
        all_duration_snips.append(res["durations"])
        all_song_ids.append(np.full(n_snips, song_id, dtype=np.int32))
        all_genres.append(res["genres"])
        all_snippet_labels.append(res["labels"])
        all_start_indices.append(res["start_indices"])
        all_end_indices.append(res["end_indices"])
        all_start_qs.append(res["start_qs"])
        all_end_qs.append(res["end_qs"])
        all_start_secs.append(res["start_secs"])
        all_end_secs.append(res["end_secs"])

        new_midi_filenames_list.append(res["filename"])

    # ================================
    # MERGE + SAVE
    # ================================
    if not all_interval_snips:
        print("No snippets extracted from selected MIDI files. Dataset unchanged.")
        return

    new_intervals = np.vstack(all_interval_snips)
    new_durations = np.vstack(all_duration_snips)
    new_ids = np.concatenate(all_song_ids)
    new_genres = np.concatenate(all_genres)
    new_labels = np.concatenate(all_snippet_labels)
    new_start_indices = np.concatenate(all_start_indices)
    new_end_indices = np.concatenate(all_end_indices)
    new_start_qs = np.concatenate(all_start_qs)
    new_end_qs = np.concatenate(all_end_qs)
    new_start_secs = np.concatenate(all_start_secs)
    new_end_secs = np.concatenate(all_end_secs)

    if existing_intervals is not None and not rebuild_all:
        intervals_arr = np.vstack([existing_intervals, new_intervals])
        durations_arr = np.vstack([existing_durations, new_durations])
        song_ids_arr = np.concatenate([existing_song_ids, new_ids])

        if existing_genres is not None:
            genres_arr = np.concatenate([existing_genres, new_genres])
        else:
            genres_arr = np.concatenate(
                [np.array(["unknown"] * existing_intervals.shape[0], dtype=object), new_genres]
            )

        if existing_snippet_labels is not None:
            labels_arr = np.concatenate([existing_snippet_labels, new_labels])
        else:
            labels_arr = new_labels

        if existing_start_indices is not None:
            start_idx_arr = np.concatenate([existing_start_indices, new_start_indices])
        else:
            start_idx_arr = new_start_indices

        if existing_end_indices is not None:
            end_idx_arr = np.concatenate([existing_end_indices, new_end_indices])
        else:
            end_idx_arr = new_end_indices

        if existing_start_qs is not None:
            start_q_arr = np.concatenate([existing_start_qs, new_start_qs])
        else:
            start_q_arr = new_start_qs

        if existing_end_qs is not None:
            end_q_arr = np.concatenate([existing_end_qs, new_end_qs])
        else:
            end_q_arr = new_end_qs

        if existing_start_secs is not None:
            start_sec_arr = np.concatenate([existing_start_secs, new_start_secs])
        else:
            start_sec_arr = new_start_secs

        if existing_end_secs is not None:
            end_sec_arr = np.concatenate([existing_end_secs, new_end_secs])
        else:
            end_sec_arr = new_end_secs

        midi_filenames_arr = np.array(existing_filename_list + new_midi_filenames_list)

    else:
        intervals_arr = new_intervals
        durations_arr = new_durations
        song_ids_arr = new_ids
        genres_arr = new_genres
        labels_arr = new_labels
        start_idx_arr = new_start_indices
        end_idx_arr = new_end_indices
        start_q_arr = new_start_qs
        end_q_arr = new_end_qs
        start_sec_arr = new_start_secs
        end_sec_arr = new_end_secs
        midi_filenames_arr = np.array(new_midi_filenames_list)

    # Save final dataset
    np.savez_compressed(
        out_path,
        intervals=intervals_arr,
        durations=durations_arr,
        song_ids=song_ids_arr,
        midi_filenames=midi_filenames_arr,
        genres=genres_arr,
        snippet_labels=labels_arr,
        snippet_start_indices=start_idx_arr,
        snippet_end_indices=end_idx_arr,
        snippet_start_qs=start_q_arr,
        snippet_end_qs=end_q_arr,
        snippet_start_secs=start_sec_arr,
        snippet_end_secs=end_sec_arr,
    )

    print("\n✅ Saved final dataset (parallel, aligned):", out_path)
    print("Total snippets:", intervals_arr.shape[0])
    print("Total songs:", len(midi_filenames_arr))

# %%
process_all_midis_new_with_sec_parallel(
    rebuild_all=True,
    counts=-1,        # or some smaller number for testing
    num_workers=8     # set to number of CPU cores or slightly less
)
# Out:
# Rebuilding dataset from scratch (ignoring existing snippets.npz).
# Found 928 total MIDI files.
# 928 new file(s) before limiting by counts.
# Processing all 928 file(s)
# Using 8 worker process(es).
#   [info] pick_melody_part: selected by stats: part_name='[mariah carey] dreamlover', avg_pitch=62.6, n_notes=686
#   [info] pick_melody_part: selected by name heuristic: part_name='rhythm guitar', avg_pitch=78.0, n_notes=1
#   [worker] All the Young Dudes.mid: too few melodic events (1).
#   [info] pick_melody_part: selected by name heuristic: part_name='saw wave', avg_pitch=68.5, n_notes=231
#   [info] pick_melody_part: selected by stats: part_name='untitled', avg_pitch=57.8, n_notes=1196
#   [info] pick_melody_part: selected by stats: part_name='polysynth', avg_pitch=72.5, n_notes=1152
#   [info] pick_melody_part: selected by name heuristic: part_name='mama mia', avg_pitch=66.8, n_notes=953
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Axel_F_1.mid
#   [info] pick_melody_part: selected by stats: part_name='acoustic guitar', avg_pitch=60.2, n_notes=544
#   [info] pick_melody_part: selected by stats: part_name='track 8', avg_pitch=76.3, n_notes=524
#   [info] pick_melody_part: selected by name heuristic: part_name='lead 6 (voice)', avg_pitch=77.6, n_notes=687
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Closer.mid
#   [info] pick_melody_part: selected by name heuristic: part_name='m #3', avg_pitch=74.2, n_notes=621
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Asche_Und_Glut.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_A. Baker Sweet Love.mid
#   [info] pick_melody_part: selected by stats: part_name='dropsofj', avg_pitch=59.4, n_notes=1034
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Credence _ Up Around the Bend L.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Devil.mid
#   [info] pick_melody_part: selected by stats: part_name='synth', avg_pitch=75.1, n_notes=869
#   [info] pick_melody_part: selected by stats: part_name='xylophone', avg_pitch=72.9, n_notes=928
#   [info] pick_melody_part: selected by name heuristic: part_name='melody', avg_pitch=66.2, n_notes=155
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Good Vibrations.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_EMRunaway.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Freestyler _ Bomfunk.mid
#   [info] pick_melody_part: selected by name heuristic: part_name='give a little bit', avg_pitch=60.7, n_notes=1756
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_219Mariah_Carey___Dreamlover.mid
#   [info] pick_melody_part: selected by name heuristic: part_name='tk4', avg_pitch=69.3, n_notes=196
#   [info] pick_melody_part: selected by name heuristic: part_name='holdonim', avg_pitch=67.4, n_notes=625
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Help Me.mid
#   [info] pick_melody_part: selected by stats: part_name='alto saxophone', avg_pitch=73.3, n_notes=444
#   [info] pick_melody_part: selected by stats: part_name='how will i know                 ;george merrill / shannon rubicam / narada m. walden', avg_pitch=67.5, n_notes=1141
#   [info] pick_melody_part: selected by stats: part_name='synth', avg_pitch=77.4, n_notes=178
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_I Never Break Your Heart (3129).mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_I Wanna Be Down.mid
#   [info] pick_melody_part: selected by stats: part_name='accordeon', avg_pitch=71.3, n_notes=155
#   [info] pick_melody_part: selected by stats: part_name='tenor saxophone', avg_pitch=69.2, n_notes=353
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Ik_Zag_Twee_Beren.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_I Want You Back.mid
#   [info] pick_melody_part: selected by stats: part_name='vibraphone', avg_pitch=57.0, n_notes=693
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Badcaseoflovinyou(Robertpalmer) L.mid
#   [info] pick_melody_part: selected by stats: part_name='electric guitar', avg_pitch=57.0, n_notes=919
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Abba _ Mamma Mia L 1.mid
#   [info] pick_melody_part: selected by name heuristic: part_name='melody', avg_pitch=72.8, n_notes=336
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_M. Carey Without You.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Dropsofj.mid
#   [info] pick_melody_part: selected by stats: part_name='tell him - exiters', avg_pitch=80.2, n_notes=330
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Killing in the Name of.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Holdonim.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Luis Aguile Dile.mid
#   [info] pick_melody_part: selected by stats: part_name='untitled', avg_pitch=66.0, n_notes=317
#   [info] pick_melody_part: selected by stats: part_name='e.piano 1', avg_pitch=70.5, n_notes=475
#   [info] pick_melody_part: selected by name heuristic: part_name='rhodes piano', avg_pitch=69.0, n_notes=171
#   [info] pick_melody_part: selected by stats: part_name='morethan', avg_pitch=59.0, n_notes=1068
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Miss_You_Like_Crazy_3.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Midnight at the Oasis.mid
#   [info] pick_melody_part: selected by name heuristic: part_name='trumpet', avg_pitch=68.3, n_notes=301
#   [info] pick_melody_part: selected by stats: part_name='sampler', avg_pitch=59.0, n_notes=857
#   [info] pick_melody_part: selected by stats: part_name='clean guitar', avg_pitch=63.8, n_notes=906
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_More More More.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_JACKSON.Smooth criminal K.mid
#   [info] pick_melody_part: selected by stats: part_name='neverend', avg_pitch=79.5, n_notes=1250
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Mr.Jones.mid
#   [info] pick_melody_part: selected by stats: part_name='outreach', avg_pitch=60.4, n_notes=888
#   [info] pick_melody_part: selected by name heuristic: part_name='melody', avg_pitch=66.2, n_notes=576
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Nothing_Gonna_Stop_Us.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Morethan.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Mama _ Alesis.mid
#   [info] pick_melody_part: selected by name heuristic: part_name='trumpet', avg_pitch=72.2, n_notes=82
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_How Will I Know.mid
#   [info] pick_melody_part: selected by stats: part_name='electric bass', avg_pitch=71.5, n_notes=57
#   [info] pick_melody_part: selected by stats: part_name='electric piano', avg_pitch=58.7, n_notes=108
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Peg.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Poly 296.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Out_Of_Reach.mid
#   [info] pick_melody_part: selected by name heuristic: part_name='melody & lyric', avg_pitch=61.2, n_notes=343
#   [info] pick_melody_part: selected by stats: part_name='alto sax', avg_pitch=73.4, n_notes=405
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Poly 1606.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Poison Arrow.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Ricky Martin _ Vuelve.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Mr Mister _ Broken Wings L.mid
#   [info] pick_melody_part: selected by name heuristic: part_name='pan flute', avg_pitch=76.3, n_notes=568
#   [info] pick_melody_part: selected by stats: part_name='organ', avg_pitch=73.2, n_notes=184
#   [info] pick_melody_part: selected by stats: part_name='electric guitar', avg_pitch=68.6, n_notes=802
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Givealittlebit 1.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Selena Como L a Flor.mid
#   [info] pick_melody_part: selected by stats: part_name='fretless bass', avg_pitch=41.5, n_notes=56
#   [info] pick_melody_part: selected by stats: part_name='quito - ecuador', avg_pitch=60.6, n_notes=331
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Singforthemoment_Eminem.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Rosana El Talismßn 4.mid
#   [info] pick_melody_part: selected by stats: part_name='', avg_pitch=75.3, n_notes=990
#   [info] pick_melody_part: selected by name heuristic: part_name='sweet sixteen                   ;b.b.', avg_pitch=64.7, n_notes=811
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Shakira _ Tu.mid
#   [info] pick_melody_part: selected by name heuristic: part_name='melody', avg_pitch=74.5, n_notes=425
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Sweet Talkin Woman.mid
#   [info] pick_melody_part: selected by name heuristic: part_name='tears of a clown', avg_pitch=66.2, n_notes=819
#   [info] pick_melody_part: selected by stats: part_name='untitled', avg_pitch=59.3, n_notes=604
#   [info] pick_melody_part: selected by name heuristic: part_name='melody', avg_pitch=68.8, n_notes=329
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Ring My Bell.mid  [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Neverend.mid
#
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Take_The_Money_And_Run.mid
#   [info] pick_melody_part: selected by stats: part_name='piano', avg_pitch=63.0, n_notes=827
#   [info] pick_melody_part: selected by name heuristic: part_name='fast car - tracy chapman', avg_pitch=69.5, n_notes=653
#   [info] pick_melody_part: selected by stats: part_name='piano', avg_pitch=75.1, n_notes=176
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Together Forever.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Tracy Chapman Fast Car.mid
#   [info] pick_melody_part: selected by name heuristic: part_name='melody', avg_pitch=75.7, n_notes=313
#   [info] pick_melody_part: selected by name heuristic: part_name='we've only just begun           ;paul williams / roger nichols', avg_pitch=65.1, n_notes=1028
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_The Cranberries Zombie.mid
#   [info] pick_melody_part: selected by stats: part_name='we didn't start the fire        ;words and music by billy joel', avg_pitch=68.8, n_notes=932
#   [info] pick_melody_part: selected by stats: part_name='whenever you call', avg_pitch=60.2, n_notes=936
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_STING.Fragile K.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Stopinthenameoflove L.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_We've Only Just Begun.mid
#   [info] pick_melody_part: selected by stats: part_name='where do', avg_pitch=63.6, n_notes=851
#   [info] pick_melody_part: selected by name heuristic: part_name='whenyour', avg_pitch=55.6, n_notes=1289
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Sweet Sixteen(Bbking) L.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_The Letter.mid
#   [info] pick_melody_part: selected by stats: part_name='who do you think you are', avg_pitch=70.7, n_notes=989
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Wheneveryoucall.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Tears Of A Clown.mid
#   [info] pick_melody_part: selected by stats: part_name='midi', avg_pitch=59.6, n_notes=927
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_We Didn't Start The Fire.mid
#   [info] pick_melody_part: selected by stats: part_name='youcanta', avg_pitch=68.4, n_notes=1656
#   [info] pick_melody_part: selected by stats: part_name='addctdgs.mid', avg_pitch=60.2, n_notes=536
#   [info] pick_melody_part: selected by stats: part_name='gtr.1 (clean)', avg_pitch=64.6, n_notes=435
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_addictedtolove.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_You've_Lost_That_Loving_Feeling_1.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Whenyour.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Who Do You Think you Are.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_alicechains.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Where_Do_You_Go_1.mid
#   [info] pick_melody_part: selected by name heuristic: part_name='rhodes', avg_pitch=57.8, n_notes=685
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_alloutoflove.mid
#   [info] pick_melody_part: selected by stats: part_name='alto sax', avg_pitch=61.6, n_notes=215
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_blueyes.mid
#   [info] pick_melody_part: selected by stats: part_name='sampler', avg_pitch=80.3, n_notes=260
#   [info] pick_melody_part: selected by name heuristic: part_name='g.rhythm 2', avg_pitch=70.0, n_notes=297
#   [info] pick_melody_part: selected by stats: part_name='eyeofthe', avg_pitch=58.3, n_notes=1086
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_endlessl.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_brickhouse.mid
#   [info] pick_melody_part: selected by stats: part_name='stringinstrument', avg_pitch=64.6, n_notes=1339
#   [info] pick_melody_part: selected by name heuristic: part_name='melody', avg_pitch=77.8, n_notes=318
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_eyetiger2.mid
#   [info] pick_melody_part: selected by name heuristic: part_name='flute', avg_pitch=74.3, n_notes=86
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_california_dreamin5_F120.mid
#   [info] pick_melody_part: selected by stats: part_name='untitled', avg_pitch=73.1, n_notes=1004
#   [info] pick_melody_part: selected by stats: part_name='sc88pro', avg_pitch=66.2, n_notes=916
#   [info] pick_melody_part: selected by stats: part_name='guitar 2', avg_pitch=64.4, n_notes=948
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_dj_sakin_&_friends__protect_your_mind__unknown.mid
#   [info] pick_melody_part: selected by stats: part_name='acoustic bass', avg_pitch=63.4, n_notes=1530
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_eyeofthe.mid
#   [info] pick_melody_part: selected by name heuristic: part_name='flute', avg_pitch=79.9, n_notes=200
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_intrlude.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_i_cant_get_no_satisfaction1_A138.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_foreverl.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_happy_heart_G118.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Youcanta.mid
#   [info] pick_melody_part: selected by stats: part_name='low strings', avg_pitch=67.8, n_notes=86
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_paglisan.mid
#   [info] pick_melody_part: selected by stats: part_name='written by the goo goo dolls', avg_pitch=63.7, n_notes=564
#   [info] pick_melody_part: selected by stats: part_name='piano', avg_pitch=67.1, n_notes=438
#   [info] pick_melody_part: selected by stats: part_name='electric bass', avg_pitch=37.6, n_notes=663
#   [info] pick_melody_part: selected by stats: part_name='taiko', avg_pitch=54.6, n_notes=1123
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_iris3.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_ram_jam_black_betty.mid
#   [info] pick_melody_part: selected by name heuristic: part_name='unnamed-001', avg_pitch=65.5, n_notes=264
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_nessum_dorma.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_sweet_caroline6_A130.mid
#   [info] pick_melody_part: selected by name heuristic: part_name='electric bass', avg_pitch=60.7, n_notes=110
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_inthesummertime2.mid
#   [info] pick_melody_part: selected by name heuristic: part_name='solo guitar ( jack white)standard tuning', avg_pitch=65.6, n_notes=93
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_whtestr.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_266.mid
#   [info] pick_melody_part: selected by stats: part_name='electric piano', avg_pitch=64.3, n_notes=328
#   [info] pick_melody_part: selected by name heuristic: part_name='0552more', avg_pitch=60.9, n_notes=1223
#   [info] pick_melody_part: selected by stats: part_name='vibraphone', avg_pitch=63.4, n_notes=1548
#   [info] pick_melody_part: selected by stats: part_name='glockenspiel', avg_pitch=91.9, n_notes=52
#   [info] pick_melody_part: selected by name heuristic: part_name='flute 2', avg_pitch=70.1, n_notes=106
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_A. Yankovic Like a Surgeon.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_musicnight3.mid
#   [info] pick_melody_part: selected by stats: part_name='organ', avg_pitch=77.7, n_notes=204
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_staytog.mid
#   [info] pick_melody_part: selected by stats: part_name='vibraphone', avg_pitch=69.4, n_notes=533
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_tyrese.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_883___La_regina_del_celebrita'_remix[1].mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_A_Little_Bit_More_2.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_its_alright_now1_D120.mid
#   [info] pick_melody_part: selected by stats: part_name='alex', avg_pitch=55.0, n_notes=540
#   [info] pick_melody_part: selected by stats: part_name='sampler', avg_pitch=62.4, n_notes=499
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_ArcticMonkeys_Fake_tales_of_San_Francisco.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Abba Super Trouper 66.mid
#   [info] pick_melody_part: selected by name heuristic: part_name='sundaygi.mid', avg_pitch=57.1, n_notes=614
#   [info] pick_melody_part: selected by stats: part_name='alarmstu', avg_pitch=62.7, n_notes=1660
#   [info] pick_melody_part: selected by name heuristic: part_name='melody', avg_pitch=69.9, n_notes=476
#   [info] pick_melody_part: selected by name heuristic: part_name='melody', avg_pitch=66.6, n_notes=285
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Angel Eyes (Kar).mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Boney M. Sunny.mid
#   [info] pick_melody_part: selected by name heuristic: part_name='0501eyes', avg_pitch=67.5, n_notes=1154
#   [info] pick_melody_part: selected by name heuristic: part_name='02- charang lead', avg_pitch=50.6, n_notes=114
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Cardigans Myfavouritegame.mid
#   [info] pick_melody_part: selected by stats: part_name='untitled', avg_pitch=63.8, n_notes=267
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Blondie _ Sunday Girl.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_tinh_nhu_chiec_la.mid
#   [info] pick_melody_part: selected by stats: part_name='celine dion - i'm alive', avg_pitch=55.8, n_notes=1455
#   [info] pick_melody_part: selected by stats: part_name='main synth', avg_pitch=71.6, n_notes=640
#   [info] pick_melody_part: selected by name heuristic: part_name='baby when the light', avg_pitch=63.8, n_notes=1030
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_D _ Moreandmore.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Cidade Negra _ O Ere.mid
#   [info] pick_melody_part: selected by stats: part_name='accoustic grand piano', avg_pitch=62.8, n_notes=454
#   [info] pick_melody_part: selected by name heuristic: part_name='melody', avg_pitch=64.7, n_notes=411
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Duke of Earl.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_D _ Oohaahjustalittlebit 1.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Can't_Take_My_Eyes_Off_You_1.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Alarmstu.mid
#   [info] pick_melody_part: selected by stats: part_name='love to see you cry             ;iglesias/taylor/barry/torch', avg_pitch=63.5, n_notes=1403
#   [info] pick_melody_part: selected by name heuristic: part_name='lead 2 (sawtooth)', avg_pitch=46.8, n_notes=94
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Erasure _ Oh Lamo.mid
#   [info] pick_melody_part: selected by stats: part_name='pida me la', avg_pitch=58.3, n_notes=588
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_DavidGuetta_Baby_when_the_light.mid
#   [info] pick_melody_part: selected by stats: part_name='acoustic guitar', avg_pitch=66.2, n_notes=658
#   [info] pick_melody_part: selected by stats: part_name='so falta voce', avg_pitch=61.6, n_notes=1004
#   [info] pick_melody_part: selected by name heuristic: part_name='hot in the city                 ;words and music by billy idol', avg_pitch=64.8, n_notes=1015
#   [info] pick_melody_part: selected by stats: part_name='fascinated', avg_pitch=66.5, n_notes=1726
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_I Am the City.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Fascinated.mid
#   [info] pick_melody_part: selected by name heuristic: part_name='hitbit', avg_pitch=65.5, n_notes=1256
#   [info] pick_melody_part: selected by stats: part_name='itsraini', avg_pitch=59.9, n_notes=1159
#   [info] pick_melody_part: selected by name heuristic: part_name='itsmypar', avg_pitch=70.5, n_notes=556
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_GIPSY KING.Pida me la.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_E. Iglesias Love to See You Cry.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_C E L I N E_D I O N_im_alive.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Hot in the City.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Guilherme E Santiago _ So Falta Voce.mid
#   [info] pick_melody_part: selected by name heuristic: part_name='iwontlet', avg_pitch=61.4, n_notes=662
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Itsmypar.mid
#   [info] pick_melody_part: selected by stats: part_name='electric bass', avg_pitch=63.3, n_notes=890
#   [info] pick_melody_part: selected by stats: part_name='polysynth', avg_pitch=73.9, n_notes=386
#   [info] pick_melody_part: selected by stats: part_name='t 1 mc 5', avg_pitch=62.2, n_notes=809
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Iwontlet.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_ITSRAINI.mid
#   [info] pick_melody_part: selected by stats: part_name='piccolo', avg_pitch=68.7, n_notes=1410
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Hands_Up_(Give_Me_Your_Heart)_2.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Keep_On_Movin'.mid
#   [info] pick_melody_part: selected by name heuristic: part_name='melody', avg_pitch=70.5, n_notes=343
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Love Comes Quickly.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_JessicaSimpson_Angels.mid
#   [info] pick_melody_part: selected by name heuristic: part_name='love is a stranger              ;annie lennox / david stewart', avg_pitch=67.3, n_notes=1190
#   [info] pick_melody_part: selected by name heuristic: part_name='#eg.rhode', avg_pitch=66.1, n_notes=128
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Leonardo _ Amanha.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Medley.mid
#   [info] pick_melody_part: selected by stats: part_name='track-1', avg_pitch=59.8, n_notes=1793
#   [info] pick_melody_part: selected by stats: part_name='percussion', avg_pitch=54.3, n_notes=408
#   [info] pick_melody_part: selected by stats: part_name='lose', avg_pitch=89.5, n_notes=1356
#   [info] pick_melody_part: selected by name heuristic: part_name='melody', avg_pitch=62.1, n_notes=542
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Mexico.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Motorcycle___AsTheRushComesversion2__djcrayzee_20130129021259.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_MissyElliot_Lose_control.mid
#   [info] pick_melody_part: selected by stats: part_name='syn str 1', avg_pitch=71.4, n_notes=389
#   [info] pick_melody_part: selected by stats: part_name='echovoisecenter', avg_pitch=66.2, n_notes=532
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_One_In_A_Million.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_O_zone_Dragostea_din_tei.mid
#   [info] pick_melody_part: selected by name heuristic: part_name='braslead', avg_pitch=73.9, n_notes=128
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_One More Time 88.mid
#   [info] pick_melody_part: selected by stats: part_name='kalimba', avg_pitch=71.6, n_notes=393
#   [info] pick_melody_part: selected by stats: part_name='piano', avg_pitch=52.0, n_notes=180
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Orient_Express_2.mid
#   [info] pick_melody_part: selected by stats: part_name='*normal', avg_pitch=78.3, n_notes=428
#   [info] pick_melody_part: selected by stats: part_name='fretless bass', avg_pitch=64.9, n_notes=197
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Magnolia.mid
#   [info] pick_melody_part: selected by name heuristic: part_name='electric bass', avg_pitch=63.5, n_notes=96
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Poly 2201.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Poly 1470.mid
#   [info] pick_melody_part: selected by stats: part_name='viola', avg_pitch=68.1, n_notes=1602
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Lara Fabian _ I Will Love Again.mid
#   [info] pick_melody_part: selected by stats: part_name='high synth', avg_pitch=71.0, n_notes=96
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Re.Locate _ Rogue.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Morning_Sky_2.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Love Is A Stranger.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Only Happy When It Rains.mid
#   [info] pick_melody_part: selected by name heuristic: part_name='0174_oye', avg_pitch=57.1, n_notes=696
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Poly 2225.mid
#   [info] pick_melody_part: selected by stats: part_name='distortion', avg_pitch=67.3, n_notes=500
#   [info] pick_melody_part: selected by stats: part_name='question', avg_pitch=64.1, n_notes=1069
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Pure_Energy.mid
#   [info] pick_melody_part: selected by name heuristic: part_name='solo guitar', avg_pitch=69.3, n_notes=143
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Red Hot Chili Peppers _ Can't Stop.mid
#   [info] pick_melody_part: selected by stats: part_name='organo', avg_pitch=79.5, n_notes=224
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Shakira Un Poco De Amor 16.mid
#   [info] pick_melody_part: selected by stats: part_name='vibraphone', avg_pitch=68.3, n_notes=603
#   [info] pick_melody_part: selected by stats: part_name='ch0073', avg_pitch=67.0, n_notes=872
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Sei Un Mito 2.mid
#   [info] pick_melody_part: selected by name heuristic: part_name='====================', avg_pitch=59.7, n_notes=1150
#   [info] pick_melody_part: selected by stats: part_name='"look of love" - abc', avg_pitch=65.4, n_notes=601
#   [info] pick_melody_part: selected by stats: part_name='summoning', avg_pitch=61.0, n_notes=1138
#   [info] pick_melody_part: selected by stats: part_name='thatdont', avg_pitch=65.1, n_notes=1227
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Summoning _ Marching Homewards.mid
#   [info] pick_melody_part: selected by stats: part_name='guitar 1', avg_pitch=56.6, n_notes=545
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Theatre of Tragedy _ Der Tanz Der Schatten (As The Shadows Dance).mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Question.mid
#   [info] pick_melody_part: selected by stats: part_name='strings', avg_pitch=53.9, n_notes=147
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_The Look Of Love.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Tiesto___Trafficversion2__Unknown_20130127084917.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_THE CLASH.Rock the casbah.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_S Club 7 _ Two in a Million.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Oye_Mi_Canto_(Hear_My_Voice)_2.mid
#   [info] pick_melody_part: selected by stats: part_name='thinking', avg_pitch=69.9, n_notes=981
#   [info] pick_melody_part: selected by stats: part_name='who's your daddy (toby keith)', avg_pitch=58.7, n_notes=1103
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Thatdont.mid  [info] pick_melody_part: selected by name heuristic: part_name='themusic', avg_pitch=72.0, n_notes=1054
#
#   [info] pick_melody_part: selected by name heuristic: part_name='trumpet', avg_pitch=70.9, n_notes=195
#   [info] pick_melody_part: selected by stats: part_name='vamonos', avg_pitch=62.2, n_notes=767
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Us 3 _ Cantaloop 2.mid
#   [info] pick_melody_part: selected by name heuristic: part_name='lead melody', avg_pitch=74.9, n_notes=222
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Ventures _ Blinded with Science.mid
#   [info] pick_melody_part: selected by stats: part_name='verdammt', avg_pitch=60.7, n_notes=1062
#   [info] pick_melody_part: selected by stats: part_name='verrueck', avg_pitch=64.1, n_notes=1215
#   [info] pick_melody_part: selected by stats: part_name='7404wcls', avg_pitch=68.7, n_notes=880
#   [info] pick_melody_part: selected by name heuristic: part_name='sologitr', avg_pitch=72.7, n_notes=130
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Wolga_Lied.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Vamonos.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Verdammt.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_TobyKeith_Whos_your_daddy.mid
#   [info] pick_melody_part: selected by name heuristic: part_name='0035stuf', avg_pitch=68.2, n_notes=624
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_We_Close_Our_Eyes.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Themusic.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Thinking.mid
#   [info] pick_melody_part: selected by stats: part_name='youspinm', avg_pitch=73.0, n_notes=436
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Verrueck.mid
#   [info] pick_melody_part: selected by stats: part_name='bracpno', avg_pitch=63.7, n_notes=953
#   [info] pick_melody_part: selected by stats: part_name='bette davis eyes  4', avg_pitch=70.9, n_notes=338
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_You_Got_It_(The_Right_Stuff)_2.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_betydaviseyes.mid
#   [info] pick_melody_part: selected by name heuristic: part_name='midi', avg_pitch=62.4, n_notes=1188
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_at_the_hop3_Ab190_danny_and_the_juniors.mid
#   [info] pick_melody_part: selected by name heuristic: part_name='trumpet', avg_pitch=73.7, n_notes=163
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_begin_the_beguine.mid
#   [info] pick_melody_part: selected by name heuristic: part_name='melody', avg_pitch=71.2, n_notes=353
#   [info] pick_melody_part: selected by name heuristic: part_name='trumpet    e6', avg_pitch=78.7, n_notes=38
#   [info] pick_melody_part: selected by name heuristic: part_name='trumpet', avg_pitch=71.4, n_notes=126
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_if_i_had_a_hammer2_D180.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_cantaloop.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Youspinm.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_concious.mid
#   [info] pick_melody_part: selected by stats: part_name='#vlo.strng', avg_pitch=73.4, n_notes=421
#   [info] pick_melody_part: selected by stats: part_name='stl strng guitar', avg_pitch=63.0, n_notes=1000
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_fable.mid
#   [info] pick_melody_part: selected by stats: part_name='your love is my drug', avg_pitch=58.7, n_notes=265
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_black_eyed_peas_i_gotta_feeling.mid
#   [info] pick_melody_part: selected by stats: part_name='tuba', avg_pitch=70.8, n_notes=495
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_inbetween.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_inthenavy.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_kesha_your_love_is_my_drug.mid
#   [info] pick_melody_part: selected by stats: part_name='electric guitar', avg_pitch=93.7, n_notes=159
#   [info] pick_melody_part: selected by name heuristic: part_name='lead vocals', avg_pitch=63.6, n_notes=492
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_213.mid
#   [info] pick_melody_part: selected by name heuristic: part_name='lead 8', avg_pitch=75.0, n_notes=152
#   [info] pick_melody_part: selected by stats: part_name='vocals', avg_pitch=61.2, n_notes=412
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_taylor_swift_love_story.mid
#   [info] pick_melody_part: selected by stats: part_name='stringinstrument', avg_pitch=73.7, n_notes=342
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_tacabro_tacata.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_rmiles.mid
#   [info] pick_melody_part: selected by stats: part_name='jon ebdon', avg_pitch=75.7, n_notes=252
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_creed_whatsthislifefor.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Atb _ 9 Pm Til I Come.mid
#   [info] pick_melody_part: selected by stats: part_name='brass', avg_pitch=73.4, n_notes=229
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_walksunshine.mid
#   [info] pick_melody_part: selected by name heuristic: part_name='bass&lead', avg_pitch=56.8, n_notes=270
#   [info] pick_melody_part: selected by stats: part_name='electric organ', avg_pitch=66.2, n_notes=986
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Chase_2.mid
#   [info] pick_melody_part: selected by name heuristic: part_name='solo', avg_pitch=74.0, n_notes=121
#   [info] pick_melody_part: selected by name heuristic: part_name='melody', avg_pitch=70.9, n_notes=447
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Before_And_After.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Charmless Man.mid
#   [info] pick_melody_part: selected by stats: part_name='alto saxophone', avg_pitch=64.9, n_notes=410
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_turnbacktime.mid
#   [info] pick_melody_part: selected by stats: part_name='blue monday', avg_pitch=67.8, n_notes=689
#   [info] pick_melody_part: selected by stats: part_name='piano', avg_pitch=75.2, n_notes=288
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_08_Dis_Dread_Is_Sure.mid
#   [info] pick_melody_part: selected by stats: part_name='staff-6', avg_pitch=61.8, n_notes=404
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Coldplay _ Trouble (RalphE's Full Club Remix).mid
#   [info] pick_melody_part: selected by stats: part_name='organ', avg_pitch=74.4, n_notes=484
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Baha Men _ Who Let the Dogs Out L.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_BuffSold.mid
#   [info] pick_melody_part: selected by stats: part_name='midi 04', avg_pitch=67.9, n_notes=72
#   [info] pick_melody_part: selected by name heuristic: part_name='lead 8 (brass + lead)', avg_pitch=61.4, n_notes=288
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_D_Code Feat. Emma _ My Direction (Styles & Breeze Remix).mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_D _ Tonightisthenight.mid
#   [info] pick_melody_part: selected by stats: part_name='con il nastro rosa', avg_pitch=71.1, n_notes=486
#   [info] pick_melody_part: selected by stats: part_name='cello', avg_pitch=71.5, n_notes=829
#   [info] pick_melody_part: selected by name heuristic: part_name='flute', avg_pitch=77.3, n_notes=387
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Con Il Nastro Rosa 67.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_D. Guetta Love Don't Let Me Go.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_D _ Myohmy.mid
#   [info] pick_melody_part: selected by name heuristic: part_name='p14-saw lead', avg_pitch=55.0, n_notes=204
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_D _ Childrenofthenight.mid
#   [info] pick_melody_part: selected by name heuristic: part_name='saw wave', avg_pitch=65.6, n_notes=32
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_D _ Rosesarered.mid
#   [info] pick_melody_part: selected by name heuristic: part_name='voice', avg_pitch=56.3, n_notes=284
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Gorillaz_Kids_with_guns.mid
#   [info] pick_melody_part: selected by name heuristic: part_name='double vocals', avg_pitch=77.1, n_notes=298
#   [info] pick_melody_part: selected by stats: part_name='slow strings', avg_pitch=92.3, n_notes=363
#   [info] pick_melody_part: selected by stats: part_name='high', avg_pitch=60.0, n_notes=1103
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Everlong.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Georges D'or Cet Anneau D'or.mid
#   [info] pick_melody_part: selected by stats: part_name='e.piano 2', avg_pitch=85.3, n_notes=91
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_I_Can't_Go_For_That_1.mid
#   [info] pick_melody_part: selected by stats: part_name='choir', avg_pitch=64.8, n_notes=333
#   [info] pick_melody_part: selected by name heuristic: part_name='bass lead', avg_pitch=42.2, n_notes=1064
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Blue Monday _ Neworder(1).mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_I Robot.mid
#   [info] pick_melody_part: selected by stats: part_name='i'm thinkin' of u', avg_pitch=69.7, n_notes=553
#   [info] pick_melody_part: selected by stats: part_name='choir aahs', avg_pitch=76.7, n_notes=102
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Girls and Boys.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Jane_Funk.mid
#   [info] pick_melody_part: selected by stats: part_name='sampler', avg_pitch=79.7, n_notes=1290
#   [info] pick_melody_part: selected by stats: part_name='piano', avg_pitch=64.8, n_notes=732
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_High.mid
#   [info] pick_melody_part: selected by stats: part_name='keinschw', avg_pitch=54.9, n_notes=1156
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_J'ai Peur En Réparation.mid
#   [info] pick_melody_part: selected by name heuristic: part_name='melody', avg_pitch=76.6, n_notes=456
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Last Train to London.mid
#   [info] pick_melody_part: selected by name heuristic: part_name='flute', avg_pitch=72.0, n_notes=6
#   [worker] Love_Is_Magic.mid: too few melodic events (6).
#   [info] pick_melody_part: selected by name heuristic: part_name='trumpet', avg_pitch=66.0, n_notes=224
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_It's_A_Rainy_Day_1.mid
#   [info] pick_melody_part: selected by stats: part_name='clavi', avg_pitch=68.2, n_notes=372
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Madonna _ Nothing Really Matters.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Keinschw.mid
#   [info] pick_melody_part: selected by stats: part_name=''jump'', avg_pitch=68.1, n_notes=130
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Madonna_Jump.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_I'm Thinking Of You.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Jammin L.mid
#   [info] pick_melody_part: selected by stats: part_name='myheartg', avg_pitch=70.6, n_notes=687
#   [info] pick_melody_part: selected by stats: part_name='next best superstar-3', avg_pitch=62.4, n_notes=371
#   [info] pick_melody_part: selected by stats: part_name='sci-fi', avg_pitch=69.3, n_notes=512
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_MelanieC_Next_best_superstar.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Living on Video.mid
#   [info] pick_melody_part: selected by stats: part_name='piano', avg_pitch=68.5, n_notes=490
#   [info] pick_melody_part: selected by stats: part_name='fretless bass', avg_pitch=70.4, n_notes=217
#   [info] pick_melody_part: selected by stats: part_name='recorder', avg_pitch=71.5, n_notes=420
#   [info] pick_melody_part: selected by stats: part_name='electric bass', avg_pitch=59.2, n_notes=108
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Noelia _ No Puedo Estar Sin Ti.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Mr_Blue.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Poly 2211.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Poly 2193.mid
#   [info] pick_melody_part: selected by stats: part_name='we are all made of stars - moby', avg_pitch=60.6, n_notes=1498
#   [info] pick_melody_part: selected by stats: part_name='boom boom boom boom', avg_pitch=66.5, n_notes=92
#   [info] pick_melody_part: selected by stats: part_name='electric bass', avg_pitch=54.5, n_notes=429
#   [info] pick_melody_part: selected by stats: part_name='you give love a bad name', avg_pitch=66.4, n_notes=128
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Poly 627.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Poly 881.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Poly 3066.mid
#   [info] pick_melody_part: selected by name heuristic: part_name='electric bass', avg_pitch=66.5, n_notes=1176
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Myheartg.mid
#   [info] pick_melody_part: selected by stats: part_name='electric organ', avg_pitch=66.6, n_notes=110
#   [info] pick_melody_part: selected by stats: part_name='iwanna roc', avg_pitch=56.2, n_notes=1118
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Poly 259.mid
#   [info] pick_melody_part: selected by name heuristic: part_name='flute', avg_pitch=83.6, n_notes=39
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Snap vs. Plaything _ Do You See The Light.mid
#   [info] pick_melody_part: selected by stats: part_name='rebelyel', avg_pitch=63.5, n_notes=838
#   [info] pick_melody_part: selected by stats: part_name='synthsound(sawtooth)', avg_pitch=75.1, n_notes=1008
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Robert Miles _ Children 2.mid
#   [info] pick_melody_part: selected by stats: part_name='bottleblow', avg_pitch=69.4, n_notes=135
#   [info] pick_melody_part: selected by name heuristic: part_name='solebdei', avg_pitch=63.5, n_notes=1812
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Power_Of_American_Natives.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Moby _ We are all made of stars.mid
#   [info] pick_melody_part: selected by stats: part_name='clavinet', avg_pitch=67.7, n_notes=578
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_PREZIOSO.I wanna rock.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Something_About_You_1.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Rebelyel.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Pet Shop Boys _ Its a Sin L.mid
#   [info] pick_melody_part: selected by stats: part_name='sampler', avg_pitch=66.7, n_notes=547
#   [info] pick_melody_part: selected by stats: part_name='superdan', avg_pitch=63.1, n_notes=2186
#   [info] pick_melody_part: selected by stats: part_name='scobidoobi', avg_pitch=69.2, n_notes=1221
#   [info] pick_melody_part: selected by name heuristic: part_name='vocals', avg_pitch=61.5, n_notes=510
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Sky 1.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Supermans Dead.mid
# ...
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Benito Di Paula _ Amigo Do Sol, Amigo Da Lua.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Groovy Kind of Love.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Cold as Ice.mid
#   [info] pick_melody_part: selected by name heuristic: part_name='flutes', avg_pitch=80.2, n_notes=17
#   [worker] God Only Knows (3397).mid: too few melodic events (17).
#   [info] pick_melody_part: selected by stats: part_name='vocals', avg_pitch=58.7, n_notes=311
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_EMKissYouAllOver.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Cranberries _ Daffodil Lament.mid
#   [info] pick_melody_part: selected by name heuristic: part_name='untitled', avg_pitch=64.4, n_notes=876
#   [info] pick_melody_part: selected by stats: part_name='ac gtr', avg_pitch=63.5, n_notes=1034
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_FooFighters_DOA.mid
#   [info] pick_melody_part: selected by name heuristic: part_name='piano', avg_pitch=66.2, n_notes=280
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_G.MICHAEL.Waiting for that day.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_HuschHuschInsKörbchen.mid
#   [info] pick_melody_part: selected by stats: part_name='guus meeuwis', avg_pitch=60.9, n_notes=1474
#   [info] pick_melody_part: selected by stats: part_name='hitbit', avg_pitch=68.3, n_notes=1155
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Hello_2.mid
#   [info] pick_melody_part: selected by stats: part_name='i take my chanc', avg_pitch=59.4, n_notes=1405
#   [info] pick_melody_part: selected by stats: part_name='0271inst', avg_pitch=64.8, n_notes=750
#   [info] pick_melody_part: selected by stats: part_name='acoustic guitar', avg_pitch=62.9, n_notes=500
#   [info] pick_melody_part: selected by stats: part_name='hitbit', avg_pitch=59.7, n_notes=1989
#   [info] pick_melody_part: selected by stats: part_name='stringinstrument', avg_pitch=67.2, n_notes=646
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_It Aint Me Babe.mid
#   [info] pick_melody_part: selected by stats: part_name='brass', avg_pitch=67.9, n_notes=454
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Il Suono Delle Campane.mid
#   [info] pick_melody_part: selected by stats: part_name='dj !gor (dj.igor@tut.by)', avg_pitch=60.1, n_notes=366
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Join_Me_3.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_I_Can_Help.mid
#   [info] pick_melody_part: selected by stats: part_name='verse guit', avg_pitch=78.6, n_notes=168
#   [info] pick_melody_part: selected by name heuristic: part_name='melody', avg_pitch=60.1, n_notes=237
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Korn _ Trash.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Io Che Amo Solo Te.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Just_A_Friend_Of_Mine.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Instant_Replay.mid
#   [info] pick_melody_part: selected by stats: part_name='acoustic guitar', avg_pitch=59.8, n_notes=1034
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Het is Een Nacht.mid
#   [info] pick_melody_part: selected by stats: part_name='laughing                        ;randy bachman / burton cummings', avg_pitch=65.2, n_notes=780
#   [info] pick_melody_part: selected by name heuristic: part_name='saw wave', avg_pitch=63.6, n_notes=139
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Laid_So_Low_(Tears_Roll_Down).mid
#   [info] pick_melody_part: selected by name heuristic: part_name='trumpet', avg_pitch=72.4, n_notes=158
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Lady Willpower.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_I Take My Chances.mid
#   [info] pick_melody_part: selected by stats: part_name='little ch', avg_pitch=62.9, n_notes=553
#   [info] pick_melody_part: selected by stats: part_name='synth', avg_pitch=75.0, n_notes=220
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Love Walks in.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Hor_Gut_Zu_1.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_L'ultimo Bicchiere.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Laughing.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Little_Children.mid
#   [info] pick_melody_part: selected by name heuristic: part_name='brass 1', avg_pitch=69.8, n_notes=104
#   [info] pick_melody_part: selected by stats: part_name='allyou10.mid', avg_pitch=59.5, n_notes=1485
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Los Abuelos De L A Nada _ Lunes Por L A Madrugada.mid
#   [info] pick_melody_part: selected by stats: part_name='likearol', avg_pitch=68.8, n_notes=2465
#   [info] pick_melody_part: selected by name heuristic: part_name='track 2', avg_pitch=64.0, n_notes=85
#   [info] pick_melody_part: selected by stats: part_name='steelstr. guitar', avg_pitch=62.7, n_notes=482
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Outta Reach _ Gabrielle.mid
#   [info] pick_melody_part: selected by stats: part_name='acoustic guitar', avg_pitch=60.8, n_notes=813
#   [info] pick_melody_part: selected by name heuristic: part_name='trumpet', avg_pitch=75.3, n_notes=103
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_My Baby Loves Lovin.mid
#   [info] pick_melody_part: selected by name heuristic: part_name='flute', avg_pitch=78.3, n_notes=96
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Ode_To_My_Family_1.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Mel C _ If That Were Me.mid
#   [info] pick_melody_part: selected by stats: part_name='fretless bass', avg_pitch=61.8, n_notes=152
#   [info] pick_melody_part: selected by stats: part_name='grunge guitar', avg_pitch=49.3, n_notes=185
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Pet.mid
#   [info] pick_melody_part: selected by stats: part_name='my girl', avg_pitch=69.9, n_notes=674
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Poly 1445.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_No_Excuses_1.mid
#   [info] pick_melody_part: selected by stats: part_name='a.piano 1', avg_pitch=73.0, n_notes=406
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Precious_And_Few.mid
#   [info] pick_melody_part: selected by name heuristic: part_name='saw wave', avg_pitch=69.7, n_notes=60
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Promise_You_Made.mid
#   [info] pick_melody_part: selected by stats: part_name='rock me my baby                 ;susan heather / shorty long', avg_pitch=58.5, n_notes=872
#   [info] pick_melody_part: selected by stats: part_name='guitar', avg_pitch=62.6, n_notes=589
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_MAVERICKS.All you do.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Piece of My Heart.mid
#   [info] pick_melody_part: selected by stats: part_name='to por ai', avg_pitch=58.5, n_notes=2301
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_My Girl_1.mid
#   [info] pick_melody_part: selected by stats: part_name='searcher', avg_pitch=68.6, n_notes=1563  [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Rock Me My baby.mid
#
#   [info] pick_melody_part: selected by name heuristic: part_name='tk13', avg_pitch=76.5, n_notes=177
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_SillyLoveSongs3.mid
#   [info] pick_melody_part: selected by stats: part_name='harpsichord', avg_pitch=79.8, n_notes=543
#   [info] pick_melody_part: selected by stats: part_name='7422sumr', avg_pitch=68.9, n_notes=810
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Strawberry Alarm Clock Incense and Peppermints.mid
#   [info] pick_melody_part: selected by stats: part_name='tabit midi - track 2', avg_pitch=59.0, n_notes=644
#   [info] pick_melody_part: selected by stats: part_name='please come home for christmas', avg_pitch=56.9, n_notes=415
#   [info] pick_melody_part: selected by stats: part_name='electric piano', avg_pitch=65.2, n_notes=1255
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_SimplePlan_Im_just_a_kid.mid
#   [info] pick_melody_part: selected by name heuristic: part_name='0215devl', avg_pitch=63.1, n_notes=813
#   [info] pick_melody_part: selected by name heuristic: part_name='quena', avg_pitch=70.4, n_notes=215
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Temblor.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_THE EAGLES.Please come home for Christmas.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Summer_Nights_(From_'Grease')_2.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Likearol.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Searcher.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_That_Ole_Devil_Called_love.mid
#   [info] pick_melody_part: selected by stats: part_name='putmes', avg_pitch=65.7, n_notes=1353
#   [info] pick_melody_part: selected by stats: part_name='piste 1', avg_pitch=48.6, n_notes=879
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_aerials.mid
#   [info] pick_melody_part: selected by stats: part_name='p2-drawbar organ #', avg_pitch=72.5, n_notes=583
#   [info] pick_melody_part: selected by name heuristic: part_name='whenwear', avg_pitch=64.5, n_notes=1262
#   [info] pick_melody_part: selected by name heuristic: part_name='melody', avg_pitch=57.7, n_notes=365
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Rio Negro E Solimoes _ To Por Ai.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Zo_Ver_Weg.mid
#   [info] pick_melody_part: selected by name heuristic: part_name='melody', avg_pitch=64.7, n_notes=404
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_WoolyBully.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Time_Love_And_Tender_Me.mid
#   [info] pick_melody_part: selected by stats: part_name='amy macdonald--mr. rock and roll', avg_pitch=67.2, n_notes=1497
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_WORLD PARTY.Put the message in the box.mid
#   [info] pick_melody_part: selected by stats: part_name='2nd piccolo', avg_pitch=70.3, n_notes=531
#   [info] pick_melody_part: selected by stats: part_name='chorusedpiano', avg_pitch=62.7, n_notes=845
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_formyladymb.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Stumblin L.mid
#   [info] pick_melody_part: selected by name heuristic: part_name='mike patton', avg_pitch=75.5, n_notes=203
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_dothattome.mid
#   [info] pick_melody_part: selected by name heuristic: part_name='letras', avg_pitch=72.4, n_notes=513
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_digging_the_grave.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_Whenwear.mid
#   [info] pick_melody_part: selected by stats: part_name='gun', avg_pitch=41.3, n_notes=419
#   [info] pick_melody_part: selected by name heuristic: part_name='solo', avg_pitch=76.1, n_notes=55
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_good04.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_experiencia.mid
#   [info] pick_melody_part: selected by stats: part_name='acoustic guitar', avg_pitch=62.3, n_notes=410
#   [info] pick_melody_part: selected by name heuristic: part_name='rhythm guitar 2', avg_pitch=70.5, n_notes=614
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_hilary_duff_fly.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_heytonight.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_gun.mid
#   [info] pick_melody_part: selected by stats: part_name='daniel johns (gtr 1)', avg_pitch=47.0, n_notes=742
#   [info] pick_melody_part: selected by stats: part_name='untitled', avg_pitch=62.7, n_notes=1360  [info] pick_melody_part: selected by stats: part_name='vocal', avg_pitch=77.6, n_notes=324
#
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_living after midnight_.mid
#   [info] pick_melody_part: selected by stats: part_name='piccolo', avg_pitch=70.7, n_notes=225
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_lostinspace.mid
#   [info] pick_melody_part: selected by stats: part_name='piano', avg_pitch=88.3, n_notes=703
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_israels_son.mid
#   [info] pick_melody_part: selected by stats: part_name='guitar1', avg_pitch=58.2, n_notes=728
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_amy_macdonald_mr_rock_and_roll.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_light_my_fire.mid
#   [info] pick_melody_part: selected by name heuristic: part_name='e. r. trimble', avg_pitch=69.3, n_notes=445
#   [info] pick_melody_part: selected by name heuristic: part_name='lead voc', avg_pitch=68.1, n_notes=293
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_red_rubber_ball1_A86.mid
#   [info] pick_melody_part: selected by name heuristic: part_name='melody', avg_pitch=68.9, n_notes=267
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_plush3.mid
#   [info] pick_melody_part: selected by stats: part_name='gtr. 1', avg_pitch=59.1, n_notes=301
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_rubber_ball_gr_kar.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_use_the_man.mid
#   [info] pick_melody_part: selected by name heuristic: part_name='wishing you were', avg_pitch=68.4, n_notes=186
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_wishingyouwere.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_rocky_3.mid
#   [info] pick_melody_part: selected by name heuristic: part_name='melody', avg_pitch=72.6, n_notes=166
#   [info] pick_melody_part: selected by stats: part_name='alto', avg_pitch=63.9, n_notes=161
#   [info] pick_melody_part: selected by stats: part_name='acousgrpiano', avg_pitch=62.0, n_notes=696
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_wonderful1_Gb80_smileversion.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_turnthepage.mid
#   [info] pick_melody_part: selected by name heuristic: part_name='bottleblow', avg_pitch=75.0, n_notes=2
#   [worker] nelly_furtado_all_good_things.mid: too few melodic events (2).
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_septembermorn.mid
#   [worker] Saved transposed: ../data/processed/transposed_midis/transposed_kid_rock_all_summer_long.mid
#
# ✅ Saved final dataset (parallel, aligned): ../data/processed/snippets.npz
# Total snippets: 34513
# Total songs: 912

# %%
import numpy as np

data_old= np.load("../data/processed/snippets_old.npz", allow_pickle=True)
data= np.load("../data/processed/snippets.npz", allow_pickle=True)

# %%
print(data.files)
# Out:
# ['intervals', 'durations', 'song_ids', 'midi_filenames', 'genres', 'snippet_labels', 'snippet_start_indices', 'snippet_end_indices', 'snippet_start_qs', 'snippet_end_qs', 'snippet_start_secs', 'snippet_end_secs']

# %%
print(data_old.files)
# Out:
# ['intervals', 'durations', 'song_ids', 'midi_filenames']

# %%
data('midi_filenames','snippet_labels')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 data('midi_filenames','snippet_labels')
#
# TypeError: 'NpzFile' object is not callable

# %%
data_old['intervals']
# Out:
# array([[  0,  -3,  -5, ...,   4,   0, -11],
#        [  0,   2,  -4, ...,  -5,   0,   3],
#        [  4,   3,   4, ...,   2,  -7,   7],
#        ...,
#        [ -1,  -5,   1, ...,   0,   0,   0],
#        [  2,  -5,   3, ...,   3,   2,  -5],
#        [  0,   3, -10, ...,  -3,  -2,  -2]], dtype=int32)
