# %%
# src/preprocess_midi.py

import os
from pathlib import Path
from typing import List, Tuple

import numpy as np
from music21 import interval, pitch

# %%
# -----------------------------
# Config
# -----------------------------
RAW_MIDI_DIR = Path("../data/mini_dataset")
PROCESSED_DIR = Path("../data/processed")
PROCESSED_DIR.mkdir(parents=True, exist_ok=True)
TRANSPOSED_DIR = PROCESSED_DIR / "transposed_midis"
TRANSPOSED_DIR.mkdir(parents=True, exist_ok=True)


# how many notes per snippet (you can tweak)
SNIPPET_LENGTH = 32

# base rhythmic unit: 1 quarter note = 4 steps, so 1 step = sixteenth note
STEPS_PER_QUARTER = 4

# %%
# -----------------------------
# Helper functions
# -----------------------------

from music21 import converter, instrument, note, chord, stream, key, interval, pitch

def load_midi(filepath: Path) -> stream.Score:
    """Load a MIDI file into a music21 Score."""
    return converter.parse(str(filepath))


def pick_melody_part(score: stream.Score) -> stream.Part | None:
    """
    Heuristic for picking the 'melody' part:

    1. Skip *purely* percussion parts.
    2. If any part name/instrument name suggests 'melody/lead/right hand',
       pick that directly.
    3. Otherwise:
       - For each remaining part, compute:
         * n_notes
         * avg_pitch
       - Compute median avg_pitch across candidates.
       - Filter to parts with avg_pitch >= median (favor higher voices).
       - Among those, pick the one with the most notes; break ties by higher avg_pitch.

    Returns the chosen Part, or None if nothing suitable is found.
    """
    candidates = []

    for p in score.parts:
        insts = list(p.getInstruments())

        # Determine if this part is purely percussion (all instruments percussion-like)
        has_percussion = any(
            isinstance(i, instrument.UnpitchedPercussion) or
            ("percussion" in (i.bestName() or "").lower())
            for i in insts
        )
        has_non_percussion = any(
            not isinstance(i, instrument.UnpitchedPercussion) and
            "percussion" not in (i.bestName() or "").lower()
            for i in insts
        )

        # Skip only if it's *purely* percussion, not mixed
        if has_percussion and not has_non_percussion:
            continue

        # Collect notes/chords
        notes_chords = [n for n in p.recurse().notes if isinstance(n, (note.Note, chord.Chord))]
        if not notes_chords:
            continue

        # Basic stats
        pitches = []
        for n in notes_chords:
            if isinstance(n, note.Note):
                pitches.append(n.pitch.midi)
            elif isinstance(n, chord.Chord):
                pitches.append(max(nn.pitch.midi for nn in n.notes))

        if not pitches:
            continue

        n_notes = len(pitches)
        avg_pitch = sum(pitches) / len(pitches)

        # part/instrument names (lowercased)
        part_name = (p.partName or "").lower()
        inst_names = [str(inst.instrumentName or "").lower()
                      for inst in insts]

        candidates.append({
            "part": p,
            "n_notes": n_notes,
            "avg_pitch": avg_pitch,
            "part_name": part_name,
            "inst_names": inst_names,
        })

    if not candidates:
        print("  [warn] no suitable melodic parts; skipping this file.")
        return None

    # 1) Name-based shortcut: if any part name/instrument suggests "melody"
    name_keywords = [
        "melody", "lead", "right hand", "rh", "treble", "solo", "violin", "flute", "trumpet"
    ]

    def looks_like_melody(c):
        text = c["part_name"] + " " + " ".join(c["inst_names"])
        text = text.lower()
        return any(kw in text for kw in name_keywords)

    name_candidates = [c for c in candidates if looks_like_melody(c)]
    if name_candidates:
        # among these, pick the one with highest avg_pitch (just in case)
        best = max(name_candidates, key=lambda c: c["avg_pitch"])
        print(f"  [info] pick_melody_part: selected by name heuristic: "
              f"part_name='{best['part_name']}', avg_pitch={best['avg_pitch']:.1f}, n_notes={best['n_notes']}")
        return best["part"]

    # 2) Pitch-based filtering: keep only parts at or above median avg_pitch
    avg_pitches = [c["avg_pitch"] for c in candidates]
    median_pitch = sorted(avg_pitches)[len(avg_pitches) // 2]

    high_voice_candidates = [c for c in candidates if c["avg_pitch"] >= median_pitch]
    if not high_voice_candidates:
        high_voice_candidates = candidates  # fallback to all

    # 3) Among high-voice candidates, pick the one with the most notes & higher pitch
    best = max(
        high_voice_candidates,
        key=lambda c: (c["n_notes"], c["avg_pitch"])  # primary: many notes, secondary: higher pitch
    )

    print(
        f"  [info] pick_melody_part: selected by stats: "
        f"part_name='{best['part_name']}', avg_pitch={best['avg_pitch']:.1f}, "
        f"n_notes={best['n_notes']}"
    )

    return best["part"]




def detect_key_and_transpose(melody: stream.Part) -> stream.Part:
    """
    Detect key with music21 and transpose so tonic is C (for major) or A (for minor).
    If key detection fails for some reason, return the original melody.
    """
    try:
        key_guess = melody.analyze('key')
    except Exception as e:
        print("  [warn] key analysis failed, leaving melody untransposed:", e)
        return melody

    # Decide target tonic
    if key_guess.mode == 'major':
        target_pitch = pitch.Pitch('C')
    else:
        # treat minor keys as aiming for A minor tonic
        target_pitch = pitch.Pitch('A')

    # Build interval from current tonic to target tonic
    itvl = interval.Interval(key_guess.tonic, target_pitch)

    transposed = melody.transpose(itvl)
    return transposed


def extract_pitch_duration_sequence(melody: stream.Part) -> List[Tuple[int, float]]:
    """
    Extract (midi_pitch, quarter_length_duration) from a melody line.
    Ignore rests; collapse chords to their top note.
    """
    seq = []
    for elem in melody.recurse().notesAndRests:
        if isinstance(elem, note.Note):
            midi_pitch = elem.pitch.midi
            dur = float(elem.quarterLength)
            seq.append((midi_pitch, dur))
        elif isinstance(elem, chord.Chord):
            # take highest note in chord as melody approximation
            midi_pitch = max(n.pitch.midi for n in elem.notes)
            dur = float(elem.quarterLength)
            seq.append((midi_pitch, dur))
        else:
            # ignore rests and other stuff for now
            continue
    return seq


def convert_to_intervals_and_durations(
    pitch_dur_seq: List[Tuple[int, float]]
) -> Tuple[List[int], List[int]]:
    """
    Convert absolute pitches to pitch intervals and durations to integer steps.
    intervals[i] = pitch[i] - pitch[i-1], with first interval = 0
    durations[i] = round( quarter_length * STEPS_PER_QUARTER )
    """
    if not pitch_dur_seq:
        return [], []

    pitches = [p for (p, _) in pitch_dur_seq]
    durs_q = [d for (_, d) in pitch_dur_seq]

    intervals = [0]  # first note has no previous reference
    for i in range(1, len(pitches)):
        intervals.append(int(pitches[i] - pitches[i - 1]))

    durations = [max(1, int(round(d * STEPS_PER_QUARTER))) for d in durs_q]

    return intervals, durations


def make_snippets(
    intervals: List[int],
    durations: List[int],
    snippet_length: int = SNIPPET_LENGTH
) -> Tuple[np.ndarray, np.ndarray]:
    """
    Slice sequences into fixed-length snippets.
    We use a simple sliding window with stride = snippet_length // 2 (50% overlap).
    Short sequences yield zero snippets.
    """
    assert len(intervals) == len(durations)
    n = len(intervals)
    if n < snippet_length:
        return np.empty((0, snippet_length), dtype=np.int32), np.empty((0, snippet_length), dtype=np.int32)

    stride = snippet_length // 2
    interval_snips = []
    duration_snips = []

    for start in range(0, n - snippet_length + 1, stride):
        end = start + snippet_length
        interval_snips.append(intervals[start:end])
        duration_snips.append(durations[start:end])

    return np.array(interval_snips, dtype=np.int32), np.array(duration_snips, dtype=np.int32)

# %%
from music21 import instrument

def sanitize_melody_instrument(melody_part):
    """
    Remove any existing Instrument metadata and force a clean, non-percussion
    instrument on a non-drum channel.
    """
    # Remove ALL Instrument objects from this part
    for inst in list(melody_part.recurse().getElementsByClass(instrument.Instrument)):
        try:
            melody_part.remove(inst)
        except Exception:
            pass

    # Set a friendly part name
    melody_part.partName = "Melody"

    # Insert one clean Piano instrument at the beginning
    piano = instrument.Piano()
    piano.midiProgram = 0  # Acoustic Grand
    piano.midiChannel = 0  # Channel 1 (NOT 10/drums)
    melody_part.insert(0, piano)

    return melody_part

# %%
import warnings
from music21.midi.translate import TranslateWarning
warnings.filterwarnings("ignore", category=TranslateWarning)

# %%
# -----------------------------
# Main preprocessing
# -----------------------------
def process_all_midis(rebuild_all: bool = False):
    """
    Preprocess MIDI files into fixed-length snippets.

    Args:
        rebuild_all (bool): 
            - If False (default): 
                * Load existing snippets.npz (if present)
                * Only process NEW MIDI files not already in midi_filenames
                * Append their snippets to the existing dataset
            - If True:
                * Ignore existing snippets.npz
                * Rebuild dataset from ALL MIDI files in RAW_MIDI_DIR
    """
    out_path = PROCESSED_DIR / "snippets.npz"

    # --------------------------------------------------
    # Collect all MIDI filenames in the raw directory
    # --------------------------------------------------
    
    
    midi_files = sorted(list(RAW_MIDI_DIR.rglob("*.mid")) +
                        list(RAW_MIDI_DIR.rglob("*.midi")))

    if not midi_files:
        print(f"No MIDI files found in {RAW_MIDI_DIR}. Nothing to do.")
        return

    # We'll fill these as we go
    all_interval_snips = []
    all_duration_snips = []
    all_song_ids = []

    # These are only used if we are appending (rebuild_all=False)
    existing_intervals = None
    existing_durations = None
    existing_song_ids = None
    existing_midi_filenames = None
    existing_filenames_set = set()

    # --------------------------------------------------
    # Load existing NPZ (if present and not rebuilding)
    # --------------------------------------------------
    if not rebuild_all and out_path.exists():
        print(f"Loading existing dataset: {out_path}")
        data = np.load(out_path, allow_pickle=True)

        existing_intervals = data["intervals"]
        existing_durations = data["durations"]
        existing_song_ids = data["song_ids"]
        existing_midi_filenames = data["midi_filenames"]  # 1D array of filenames

        existing_filenames_set = set(existing_midi_filenames.tolist())

        print(f"  Existing snippets: {existing_intervals.shape[0]}")
        print(f"  Existing MIDI files: {len(existing_filenames_set)}")
    elif rebuild_all:
        print("Rebuilding dataset from scratch; ignoring existing snippets.npz (if any).")

    # --------------------------------------------------
    # Decide which files to process
    # --------------------------------------------------
    if rebuild_all or existing_midi_filenames is None:
        # process ALL files
        files_to_process = midi_files
        base_song_idx = 0
        existing_midi_filenames_list = []
    else:
        # Only process files not already in midi_filenames
        files_to_process = [p for p in midi_files if p.name not in existing_filenames_set]
        base_song_idx = len(existing_midi_filenames)
        existing_midi_filenames_list = existing_midi_filenames.tolist()

    print(f"Found {len(midi_files)} total MIDI files.")
    print(f"{len(files_to_process)} file(s) to process this run.")

    if not files_to_process:
        print("No new MIDI files found. Dataset unchanged.")
        return

    # We'll also build up the new filenames in order
    new_filenames_list = []

    # --------------------------------------------------
    # Process selected MIDI files
    # --------------------------------------------------
    for local_idx, midi_path in enumerate(files_to_process):
        # song_id for this file within the full dataset:
        # existing songs first, then new ones in order
        song_id = base_song_idx + local_idx

        print(f"Processing {midi_path.name} "
              f"({local_idx + 1}/{len(files_to_process)}), assigned song_id={song_id}")

        try:
            score = load_midi(midi_path)
        except Exception as e:
            print(f"  Failed to load {midi_path.name}: {e}")
            continue

        melody = pick_melody_part(score)
        if melody is None:
            print(f"  Skipping {midi_path.name}: no usable melodic part found.")
            continue
        melody = detect_key_and_transpose(melody)
        melody = sanitize_melody_instrument(melody)

        # Save transposed melody
        out_midi_path = TRANSPOSED_DIR / f"transposed_{midi_path.stem}.mid"
        try:
            melody.write("midi", fp=str(out_midi_path))
            print(f"  Saved transposed: {out_midi_path}")
        except Exception as e:
            print(f"  [warn] could not save transposed MIDI for {midi_path.name}: {e}")

        pitch_dur_seq = extract_pitch_duration_sequence(melody)

        if len(pitch_dur_seq) < SNIPPET_LENGTH:
            print(f"  Skipping {midi_path.name}: too few notes ({len(pitch_dur_seq)})")
            continue

        intervals, durations = convert_to_intervals_and_durations(pitch_dur_seq)
        i_snips, d_snips = make_snippets(intervals, durations, SNIPPET_LENGTH)

        if i_snips.shape[0] == 0:
            print(f"  No snippets extracted from {midi_path.name}")
            continue

        all_interval_snips.append(i_snips)
        all_duration_snips.append(d_snips)
        all_song_ids.append(np.full(i_snips.shape[0], song_id, dtype=np.int32))

        new_filenames_list.append(midi_path.name)

    # --------------------------------------------------
    # If nothing new was processed successfully
    # --------------------------------------------------
    if not all_interval_snips:
        print("No snippets extracted from selected MIDI files. Dataset unchanged.")
        return

    # Stack new snippets
    new_intervals = np.vstack(all_interval_snips)
    new_durations = np.vstack(all_duration_snips)
    new_song_ids = np.concatenate(all_song_ids)

    # --------------------------------------------------
    # Merge old + new or just use new (if rebuild_all or no existing)
    # --------------------------------------------------
    if not rebuild_all and existing_intervals is not None:
        intervals_arr = np.vstack([existing_intervals, new_intervals])
        durations_arr = np.vstack([existing_durations, new_durations])
        song_ids_arr = np.concatenate([existing_song_ids, new_song_ids])

        # Append new filenames after existing, in consistent order
        midi_filenames_arr = np.array(existing_midi_filenames_list + new_filenames_list)
    else:
        intervals_arr = new_intervals
        durations_arr = new_durations
        song_ids_arr = new_song_ids

        # When rebuilding, our song_ids are aligned with files_to_process in order
        # but we still want the full midi_files list in case some were skipped.
        midi_filenames_arr = np.array(new_filenames_list)

    # --------------------------------------------------
    # Save updated dataset
    # --------------------------------------------------
    np.savez_compressed(
        out_path,
        intervals=intervals_arr,
        durations=durations_arr,
        song_ids=song_ids_arr,
        midi_filenames=midi_filenames_arr,
    )

    print(f"Saved updated snippets to {out_path}")
    print(f"Total snippets: {intervals_arr.shape[0]}")
    print(f"Total MIDI files represented: {len(midi_filenames_arr)}")

# %%
process_all_midis(rebuild_all=True)
# Out:
# Rebuilding dataset from scratch; ignoring existing snippets.npz (if any).
# Found 908 total MIDI files.
# 908 file(s) to process this run.
# Processing A. Baker Sweet Love.mid (1/908), assigned song_id=0
#   [info] pick_melody_part: selected by stats: part_name='track 8', avg_pitch=76.3, n_notes=524
#   Saved transposed: ../data/processed/transposed_midis/transposed_A. Baker Sweet Love.mid
# Processing Abba _ Mamma Mia L 1.mid (2/908), assigned song_id=1
#   [info] pick_melody_part: selected by name heuristic: part_name='mama mia', avg_pitch=66.8, n_notes=953
#   Saved transposed: ../data/processed/transposed_midis/transposed_Abba _ Mamma Mia L 1.mid
# Processing Asche_Und_Glut.mid (3/908), assigned song_id=2
#   [info] pick_melody_part: selected by stats: part_name='polysynth', avg_pitch=72.5, n_notes=1152
#   Saved transposed: ../data/processed/transposed_midis/transposed_Asche_Und_Glut.mid
# Processing Axel_F_1.mid (4/908), assigned song_id=3
#   [info] pick_melody_part: selected by stats: part_name='bandneon', avg_pitch=83.9, n_notes=145
#   Saved transposed: ../data/processed/transposed_midis/transposed_Axel_F_1.mid
# Processing Badcaseoflovinyou(Robertpalmer) L.mid (5/908), assigned song_id=4
#   [info] pick_melody_part: selected by stats: part_name='untitled', avg_pitch=57.8, n_notes=1196
#   Saved transposed: ../data/processed/transposed_midis/transposed_Badcaseoflovinyou(Robertpalmer) L.mid
# Processing Bryan Adams _ Dream on.mid (6/908), assigned song_id=5
#   [info] pick_melody_part: selected by stats: part_name='clean guitar', avg_pitch=62.7, n_notes=595
#   Saved transposed: ../data/processed/transposed_midis/transposed_Bryan Adams _ Dream on.mid
# Processing CHUMBAWAMBA.Tubthumping.mid (7/908), assigned song_id=6
#   [info] pick_melody_part: selected by name heuristic: part_name='tubthumpi', avg_pitch=65.8, n_notes=1042
#   Saved transposed: ../data/processed/transposed_midis/transposed_CHUMBAWAMBA.Tubthumping.mid
# Processing Candleinthewinddi.mid (8/908), assigned song_id=7
#   [info] pick_melody_part: selected by stats: part_name='the funeral of diana, princess of wales on saturday september 6 1997', avg_pitch=58.9, n_notes=1215
#   Saved transposed: ../data/processed/transposed_midis/transposed_Candleinthewinddi.mid
# Processing Christina Aguilera Genie in a Bottle.mid (9/908), assigned song_id=8
#   [info] pick_melody_part: selected by stats: part_name='sequenced by mario rol', avg_pitch=85.0, n_notes=731
#   Saved transposed: ../data/processed/transposed_midis/transposed_Christina Aguilera Genie in a Bottle.mid
# Processing Closer.mid (10/908), assigned song_id=9
#   [info] pick_melody_part: selected by name heuristic: part_name='lead 6 (voice)', avg_pitch=77.6, n_notes=687
#   Saved transposed: ../data/processed/transposed_midis/transposed_Closer.mid
# Processing Credence _ Up Around the Bend L.mid (11/908), assigned song_id=10
#   [info] pick_melody_part: selected by stats: part_name='acoustic guitar', avg_pitch=60.2, n_notes=544
#   Saved transposed: ../data/processed/transposed_midis/transposed_Credence _ Up Around the Bend L.mid
# Processing Devil.mid (12/908), assigned song_id=11
#   [info] pick_melody_part: selected by name heuristic: part_name='m #3', avg_pitch=74.2, n_notes=621
#   Saved transposed: ../data/processed/transposed_midis/transposed_Devil.mid
# Processing Dont Stand So Close to Me.mid (13/908), assigned song_id=12
#   [info] pick_melody_part: selected by stats: part_name='electric bass', avg_pitch=65.2, n_notes=286
#   Saved transposed: ../data/processed/transposed_midis/transposed_Dont Stand So Close to Me.mid
# Processing Get_Down_On_It.mid (14/908), assigned song_id=13
#   [info] pick_melody_part: selected by name heuristic: part_name='melody', avg_pitch=70.7, n_notes=673
#   Saved transposed: ../data/processed/transposed_midis/transposed_Get_Down_On_It.mid
# Processing Help Me.mid (15/908), assigned song_id=14
#   [info] pick_melody_part: selected by name heuristic: part_name='tk4', avg_pitch=69.3, n_notes=196
#   Saved transposed: ../data/processed/transposed_midis/transposed_Help Me.mid
# Processing Holdonim.mid (16/908), assigned song_id=15
#   [info] pick_melody_part: selected by name heuristic: part_name='holdonim', avg_pitch=67.4, n_notes=625
#   Saved transposed: ../data/processed/transposed_midis/transposed_Holdonim.mid
# Processing How Will I Know.mid (17/908), assigned song_id=16
#   [info] pick_melody_part: selected by stats: part_name='how will i know                 ;george merrill / shannon rubicam / narada m. walden', avg_pitch=67.5, n_notes=1141
#   Saved transposed: ../data/processed/transposed_midis/transposed_How Will I Know.mid
# Processing I Wanna Be Down.mid (18/908), assigned song_id=17
#   [info] pick_melody_part: selected by stats: part_name='synth', avg_pitch=77.4, n_notes=178
#   Saved transposed: ../data/processed/transposed_midis/transposed_I Wanna Be Down.mid
# Processing I Want You Back.mid (19/908), assigned song_id=18
#   [info] pick_melody_part: selected by stats: part_name='tenor saxophone', avg_pitch=69.2, n_notes=353
#   Saved transposed: ../data/processed/transposed_midis/transposed_I Want You Back.mid
# Processing I'm Down.mid (20/908), assigned song_id=19
#   [info] pick_melody_part: selected by stats: part_name='i'm down', avg_pitch=68.2, n_notes=627
#   Saved transposed: ../data/processed/transposed_midis/transposed_I'm Down.mid
# Processing Ik_Zag_Twee_Beren.mid (21/908), assigned song_id=20
#   [info] pick_melody_part: selected by stats: part_name='accordeon', avg_pitch=71.3, n_notes=155
#   Saved transposed: ../data/processed/transposed_midis/transposed_Ik_Zag_Twee_Beren.mid
# Processing Ironic (3172).mid (22/908), assigned song_id=21
#   [info] pick_melody_part: selected by name heuristic: part_name='melody', avg_pitch=75.1, n_notes=393
#   Saved transposed: ../data/processed/transposed_midis/transposed_Ironic (3172).mid
# Processing JACKSON.Smooth criminal K.mid (23/908), assigned song_id=22
#   [info] pick_melody_part: selected by stats: part_name='vibraphone', avg_pitch=57.0, n_notes=693
#   Saved transposed: ../data/processed/transposed_midis/transposed_JACKSON.Smooth criminal K.mid
# Processing Just.mid (24/908), assigned song_id=23
#   [info] pick_melody_part: selected by stats: part_name='winjammer demo', avg_pitch=60.9, n_notes=814
#   Saved transposed: ../data/processed/transposed_midis/transposed_Just.mid
# Processing Kings and Queens.mid (25/908), assigned song_id=24
#   [info] pick_melody_part: selected by name heuristic: part_name='lead guitar', avg_pitch=70.2, n_notes=61
#   Saved transposed: ../data/processed/transposed_midis/transposed_Kings and Queens.mid
# Processing Luis Aguile Dile.mid (26/908), assigned song_id=25
#   [info] pick_melody_part: selected by stats: part_name='tell him - exiters', avg_pitch=80.2, n_notes=330
#   Saved transposed: ../data/processed/transposed_midis/transposed_Luis Aguile Dile.mid
# Processing M. Carey Without You.mid (27/908), assigned song_id=26
#   [info] pick_melody_part: selected by name heuristic: part_name='melody', avg_pitch=72.8, n_notes=336
#   Saved transposed: ../data/processed/transposed_midis/transposed_M. Carey Without You.mid
# Processing Mama _ Alesis.mid (28/908), assigned song_id=27
#   [info] pick_melody_part: selected by stats: part_name='untitled', avg_pitch=66.0, n_notes=317
#   Saved transposed: ../data/processed/transposed_midis/transposed_Mama _ Alesis.mid
# Processing Moon_Over_Bourbon_Street_2.mid (29/908), assigned song_id=28
#   [info] pick_melody_part: selected by name heuristic: part_name='melody', avg_pitch=70.1, n_notes=326
#   Saved transposed: ../data/processed/transposed_midis/transposed_Moon_Over_Bourbon_Street_2.mid
# Processing More More More.mid (30/908), assigned song_id=29
#   [info] pick_melody_part: selected by name heuristic: part_name='trumpet', avg_pitch=68.3, n_notes=301
#   Saved transposed: ../data/processed/transposed_midis/transposed_More More More.mid
# Processing Morethan.mid (31/908), assigned song_id=30
#   [info] pick_melody_part: selected by stats: part_name='morethan', avg_pitch=59.0, n_notes=1068
#   Saved transposed: ../data/processed/transposed_midis/transposed_Morethan.mid
# Processing Mr Mister _ Broken Wings L.mid (32/908), assigned song_id=31
#   [info] pick_melody_part: selected by stats: part_name='sampler', avg_pitch=59.0, n_notes=857
#   Saved transposed: ../data/processed/transposed_midis/transposed_Mr Mister _ Broken Wings L.mid
# Processing Mr.Jones.mid (33/908), assigned song_id=32
#   [info] pick_melody_part: selected by stats: part_name='clean guitar', avg_pitch=63.8, n_notes=906
#   Saved transposed: ../data/processed/transposed_midis/transposed_Mr.Jones.mid
# Processing Nothing_Gonna_Stop_Us.mid (34/908), assigned song_id=33
#   [info] pick_melody_part: selected by name heuristic: part_name='melody', avg_pitch=66.2, n_notes=576
#   Saved transposed: ../data/processed/transposed_midis/transposed_Nothing_Gonna_Stop_Us.mid
# Processing Out_Of_Reach.mid (35/908), assigned song_id=34
#   [info] pick_melody_part: selected by stats: part_name='outreach', avg_pitch=60.4, n_notes=888
#   Saved transposed: ../data/processed/transposed_midis/transposed_Out_Of_Reach.mid
# Processing Outstanding.mid (36/908), assigned song_id=35
#   [info] pick_melody_part: selected by name heuristic: part_name='lead', avg_pitch=70.4, n_notes=557
#   Saved transposed: ../data/processed/transposed_midis/transposed_Outstanding.mid
# Processing Peg.mid (37/908), assigned song_id=36
#   [info] pick_melody_part: selected by name heuristic: part_name='trumpet', avg_pitch=72.2, n_notes=82
#   Saved transposed: ../data/processed/transposed_midis/transposed_Peg.mid
# Processing Peggy_Sue_1.mid (38/908), assigned song_id=37
#   [info] pick_melody_part: selected by name heuristic: part_name='melody', avg_pitch=56.4, n_notes=265
#   Saved transposed: ../data/processed/transposed_midis/transposed_Peggy_Sue_1.mid
# Processing Play_That_Funky_Music.mid (39/908), assigned song_id=38
#   [info] pick_melody_part: selected by name heuristic: part_name='melody', avg_pitch=63.0, n_notes=553
#   Saved transposed: ../data/processed/transposed_midis/transposed_Play_That_Funky_Music.mid
# Processing Poison Arrow.mid (40/908), assigned song_id=39
#   [info] pick_melody_part: selected by name heuristic: part_name='melody & lyric', avg_pitch=61.2, n_notes=343
#   Saved transposed: ../data/processed/transposed_midis/transposed_Poison Arrow.mid
# Processing Poly 1606.mid (41/908), assigned song_id=40
#   [info] pick_melody_part: selected by stats: part_name='electric bass', avg_pitch=71.5, n_notes=57
#   Saved transposed: ../data/processed/transposed_midis/transposed_Poly 1606.mid
# Processing Poly 2364.mid (42/908), assigned song_id=41
#   [info] pick_melody_part: selected by stats: part_name='untitled', avg_pitch=63.6, n_notes=179
#   Saved transposed: ../data/processed/transposed_midis/transposed_Poly 2364.mid
# Processing Ricky Martin _ Vuelve.mid (43/908), assigned song_id=42
#   [info] pick_melody_part: selected by stats: part_name='alto sax', avg_pitch=73.4, n_notes=405
#   Saved transposed: ../data/processed/transposed_midis/transposed_Ricky Martin _ Vuelve.mid
# Processing Ring My Bell.mid (44/908), assigned song_id=43
#   [info] pick_melody_part: selected by stats: part_name='', avg_pitch=75.3, n_notes=990
#   Saved transposed: ../data/processed/transposed_midis/transposed_Ring My Bell.mid
# Processing Runtoyou.mid (45/908), assigned song_id=44
#   [info] pick_melody_part: selected by name heuristic: part_name='runtoyou', avg_pitch=57.9, n_notes=1218
#   Saved transposed: ../data/processed/transposed_midis/transposed_Runtoyou.mid
# Processing STING.Fragile K.mid (46/908), assigned song_id=45
#   [info] pick_melody_part: selected by stats: part_name='electric guitar', avg_pitch=68.6, n_notes=802
#   Saved transposed: ../data/processed/transposed_midis/transposed_STING.Fragile K.mid
# Processing Sade by Your Side.mid (47/908), assigned song_id=46
#   [info] pick_melody_part: selected by name heuristic: part_name='pan flute', avg_pitch=73.8, n_notes=259
#   Saved transposed: ../data/processed/transposed_midis/transposed_Sade by Your Side.mid
# Processing Shakira _ Tu.mid (48/908), assigned song_id=47
#   [info] pick_melody_part: selected by stats: part_name='quito - ecuador', avg_pitch=60.6, n_notes=331
#   Saved transposed: ../data/processed/transposed_midis/transposed_Shakira _ Tu.mid
# Processing SisterGoldenHair.mid (49/908), assigned song_id=48
#   [info] pick_melody_part: selected by stats: part_name='untitled', avg_pitch=60.9, n_notes=1171
#   Saved transposed: ../data/processed/transposed_midis/transposed_SisterGoldenHair.mid
# Processing Sleeping Satellites.mid (50/908), assigned song_id=49
#   [info] pick_melody_part: selected by stats: part_name='sleeping satellites', avg_pitch=62.5, n_notes=1165
#   Saved transposed: ../data/processed/transposed_midis/transposed_Sleeping Satellites.mid
# Processing Stopinthenameoflove L.mid (51/908), assigned song_id=50
#   [info] pick_melody_part: selected by stats: part_name='untitled', avg_pitch=59.3, n_notes=604
#   Saved transposed: ../data/processed/transposed_midis/transposed_Stopinthenameoflove L.mid
# Processing Sweet Sixteen(Bbking) L.mid (52/908), assigned song_id=51
#   [info] pick_melody_part: selected by name heuristic: part_name='sweet sixteen                   ;b.b.', avg_pitch=64.7, n_notes=811
#   Saved transposed: ../data/processed/transposed_midis/transposed_Sweet Sixteen(Bbking) L.mid
# Processing Sweet Talkin Woman.mid (53/908), assigned song_id=52
#   [info] pick_melody_part: selected by name heuristic: part_name='melody', avg_pitch=74.5, n_notes=425
#   Saved transposed: ../data/processed/transposed_midis/transposed_Sweet Talkin Woman.mid
# Processing Tainted_Love.mid (54/908), assigned song_id=53
#   [info] pick_melody_part: selected by stats: part_name='electric organ', avg_pitch=70.3, n_notes=380
#   Saved transposed: ../data/processed/transposed_midis/transposed_Tainted_Love.mid
# Processing Take_The_Money_And_Run.mid (55/908), assigned song_id=54
#   [info] pick_melody_part: selected by name heuristic: part_name='melody', avg_pitch=68.8, n_notes=329
#   Saved transposed: ../data/processed/transposed_midis/transposed_Take_The_Money_And_Run.mid
# Processing Tears Of A Clown.mid (56/908), assigned song_id=55
#   [info] pick_melody_part: selected by name heuristic: part_name='tears of a clown', avg_pitch=66.2, n_notes=819
#   Saved transposed: ../data/processed/transposed_midis/transposed_Tears Of A Clown.mid
# Processing The Cranberries Zombie.mid (57/908), assigned song_id=56
#   [info] pick_melody_part: selected by name heuristic: part_name='melody', avg_pitch=75.7, n_notes=313
#   Saved transposed: ../data/processed/transposed_midis/transposed_The Cranberries Zombie.mid
# Processing The Letter.mid (58/908), assigned song_id=57
#   [info] pick_melody_part: selected by stats: part_name='piano', avg_pitch=63.0, n_notes=827
#   Saved transposed: ../data/processed/transposed_midis/transposed_The Letter.mid
# Processing Together Forever.mid (59/908), assigned song_id=58
#   [info] pick_melody_part: selected by stats: part_name='piano', avg_pitch=75.1, n_notes=176
#   Saved transposed: ../data/processed/transposed_midis/transposed_Together Forever.mid
# Processing Vampire.mid (60/908), assigned song_id=59
#   [info] pick_melody_part: selected by name heuristic: part_name='fretless bass', avg_pitch=46.4, n_notes=561
#   Saved transposed: ../data/processed/transposed_midis/transposed_Vampire.mid
# Processing We Didn't Start The Fire.mid (61/908), assigned song_id=60
#   [info] pick_melody_part: selected by stats: part_name='we didn't start the fire        ;words and music by billy joel', avg_pitch=68.8, n_notes=932
#   Saved transposed: ../data/processed/transposed_midis/transposed_We Didn't Start The Fire.mid
# Processing We've Only Just Begun.mid (62/908), assigned song_id=61
#   [info] pick_melody_part: selected by name heuristic: part_name='we've only just begun           ;paul williams / roger nichols', avg_pitch=65.1, n_notes=1028
#   Saved transposed: ../data/processed/transposed_midis/transposed_We've Only Just Begun.mid
# Processing West End Girls.mid (63/908), assigned song_id=62
#   [info] pick_melody_part: selected by name heuristic: part_name='trumpet', avg_pitch=73.2, n_notes=113
#   Saved transposed: ../data/processed/transposed_midis/transposed_West End Girls.mid
# Processing Where_Do_You_Go_1.mid (64/908), assigned song_id=63
#   [info] pick_melody_part: selected by stats: part_name='where do', avg_pitch=63.6, n_notes=851
#   Saved transposed: ../data/processed/transposed_midis/transposed_Where_Do_You_Go_1.mid
# Processing Who Do You Think you Are.mid (65/908), assigned song_id=64
#   [info] pick_melody_part: selected by stats: part_name='who do you think you are', avg_pitch=70.7, n_notes=989
#   Saved transposed: ../data/processed/transposed_midis/transposed_Who Do You Think you Are.mid
# Processing You've_Lost_That_Loving_Feeling_1.mid (66/908), assigned song_id=65
#   [info] pick_melody_part: selected by stats: part_name='midi', avg_pitch=59.6, n_notes=927
#   Saved transposed: ../data/processed/transposed_midis/transposed_You've_Lost_That_Loving_Feeling_1.mid
# Processing Youcanta.mid (67/908), assigned song_id=66
#   [info] pick_melody_part: selected by stats: part_name='youcanta', avg_pitch=68.4, n_notes=1656
#   Saved transposed: ../data/processed/transposed_midis/transposed_Youcanta.mid
# Processing addictedtolove.mid (68/908), assigned song_id=67
#   [info] pick_melody_part: selected by stats: part_name='addctdgs.mid', avg_pitch=60.2, n_notes=536
#   Saved transposed: ../data/processed/transposed_midis/transposed_addictedtolove.mid
# Processing backstreetthatway.mid (69/908), assigned song_id=68
#   [info] pick_melody_part: selected by stats: part_name='sampler', avg_pitch=71.4, n_notes=258
#   Saved transposed: ../data/processed/transposed_midis/transposed_backstreetthatway.mid
# Processing brickhouse.mid (70/908), assigned song_id=69
#   [info] pick_melody_part: selected by name heuristic: part_name='g.rhythm 2', avg_pitch=70.0, n_notes=297
#   Saved transposed: ../data/processed/transposed_midis/transposed_brickhouse.mid
# Processing california_dreamin5_F120.mid (71/908), assigned song_id=70
#   [info] pick_melody_part: selected by name heuristic: part_name='flute', avg_pitch=74.3, n_notes=86
#   Saved transposed: ../data/processed/transposed_midis/transposed_california_dreamin5_F120.mid
# Processing crazyonu.mid (72/908), assigned song_id=71
#   [info] pick_melody_part: selected by name heuristic: part_name='rhythm guitar', avg_pitch=59.0, n_notes=1280
#   Saved transposed: ../data/processed/transposed_midis/transposed_crazyonu.mid
# Processing dj_sakin_&_friends__protect_your_mind__unknown.mid (73/908), assigned song_id=72
#   [info] pick_melody_part: selected by stats: part_name='sc88pro', avg_pitch=66.2, n_notes=916
#   Saved transposed: ../data/processed/transposed_midis/transposed_dj_sakin_&_friends__protect_your_mind__unknown.mid
# Processing eyeofthe.mid (74/908), assigned song_id=73
#   [info] pick_melody_part: selected by stats: part_name='eyeofthe', avg_pitch=58.3, n_notes=1086
#   Saved transposed: ../data/processed/transposed_midis/transposed_eyeofthe.mid
# Processing eyetiger2.mid (75/908), assigned song_id=74
#   [info] pick_melody_part: selected by name heuristic: part_name='melody', avg_pitch=77.8, n_notes=318
#   Saved transposed: ../data/processed/transposed_midis/transposed_eyetiger2.mid
# Processing footlose.mid (76/908), assigned song_id=75
#   [info] pick_melody_part: selected by stats: part_name='sampler', avg_pitch=73.7, n_notes=402
#   Saved transposed: ../data/processed/transposed_midis/transposed_footlose.mid
# Processing foreverl.mid (77/908), assigned song_id=76
#   [info] pick_melody_part: selected by stats: part_name='stringinstrument', avg_pitch=64.6, n_notes=1339
#   Saved transposed: ../data/processed/transposed_midis/transposed_foreverl.mid
# Processing happy_heart_G118.mid (78/908), assigned song_id=77
#   [info] pick_melody_part: selected by stats: part_name='untitled', avg_pitch=73.1, n_notes=1004
#   Saved transposed: ../data/processed/transposed_midis/transposed_happy_heart_G118.mid
# Processing heyjoe2.mid (79/908), assigned song_id=78
#   [info] pick_melody_part: selected by stats: part_name='o\d gtr', avg_pitch=62.1, n_notes=205
#   Saved transposed: ../data/processed/transposed_midis/transposed_heyjoe2.mid
# Processing i_can_see_clearly_now.mid (80/908), assigned song_id=79
#   [info] pick_melody_part: selected by name heuristic: part_name='piano solo', avg_pitch=86.5, n_notes=381
#   Saved transposed: ../data/processed/transposed_midis/transposed_i_can_see_clearly_now.mid
# Processing intrlude.mid (81/908), assigned song_id=80
#   [info] pick_melody_part: selected by name heuristic: part_name='flute', avg_pitch=79.9, n_notes=200
#   Saved transposed: ../data/processed/transposed_midis/transposed_intrlude.mid
# Processing iris3.mid (82/908), assigned song_id=81
#   [info] pick_melody_part: selected by stats: part_name='written by the goo goo dolls', avg_pitch=63.7, n_notes=564
#   Saved transposed: ../data/processed/transposed_midis/transposed_iris3.mid
# Processing knokheav2.mid (83/908), assigned song_id=82
#   [info] pick_melody_part: selected by stats: part_name='piano', avg_pitch=71.2, n_notes=523
#   Saved transposed: ../data/processed/transposed_midis/transposed_knokheav2.mid
# Processing musicnight3.mid (84/908), assigned song_id=83
#   [info] pick_melody_part: selected by name heuristic: part_name='flute 2', avg_pitch=70.1, n_notes=106
#   Saved transposed: ../data/processed/transposed_midis/transposed_musicnight3.mid
# Processing nessum_dorma.mid (85/908), assigned song_id=84
#   [info] pick_melody_part: selected by stats: part_name='piano', avg_pitch=67.1, n_notes=438
#   Saved transposed: ../data/processed/transposed_midis/transposed_nessum_dorma.mid
# Processing paglisan.mid (86/908), assigned song_id=85
#   [info] pick_melody_part: selected by stats: part_name='low strings', avg_pitch=67.8, n_notes=86
#   Saved transposed: ../data/processed/transposed_midis/transposed_paglisan.mid
# Processing ram_jam_black_betty.mid (87/908), assigned song_id=86
#   [info] pick_melody_part: selected by stats: part_name='electric bass', avg_pitch=37.6, n_notes=663
#   Saved transposed: ../data/processed/transposed_midis/transposed_ram_jam_black_betty.mid
# Processing sisosig.mid (88/908), assigned song_id=87
#   [info] pick_melody_part: selected by stats: part_name='untitled', avg_pitch=57.9, n_notes=364
#   Saved transposed: ../data/processed/transposed_midis/transposed_sisosig.mid
# Processing somedaysoon.mid (89/908), assigned song_id=88
#   [info] pick_melody_part: selected by stats: part_name='* muted lyrics', avg_pitch=54.8, n_notes=269
#   Saved transposed: ../data/processed/transposed_midis/transposed_somedaysoon.mid
# Processing staytog.mid (90/908), assigned song_id=89
#   [info] pick_melody_part: selected by stats: part_name='organ', avg_pitch=77.7, n_notes=204
#   Saved transposed: ../data/processed/transposed_midis/transposed_staytog.mid
# Processing whtestr.mid (91/908), assigned song_id=90
#   [info] pick_melody_part: selected by name heuristic: part_name='solo guitar ( jack white)standard tuning', avg_pitch=65.6, n_notes=93
#   Saved transposed: ../data/processed/transposed_midis/transposed_whtestr.mid
# Processing A 1 _ Caught in the Middle.mid (92/908), assigned song_id=91
#   [info] pick_melody_part: selected by stats: part_name='a1 - caught in the middle', avg_pitch=65.6, n_notes=877
#   Saved transposed: ../data/processed/transposed_midis/transposed_A 1 _ Caught in the Middle.mid
# Processing AmyWinehouse_Rehab.mid (93/908), assigned song_id=92
#   [info] pick_melody_part: selected by stats: part_name='acoustic bass', avg_pitch=60.6, n_notes=1683
#   Saved transposed: ../data/processed/transposed_midis/transposed_AmyWinehouse_Rehab.mid
# Processing Axel_F_1.mid (94/908), assigned song_id=93
#   [info] pick_melody_part: selected by stats: part_name='bandneon', avg_pitch=83.9, n_notes=145
#   Saved transposed: ../data/processed/transposed_midis/transposed_Axel_F_1.mid
# Processing Best_ove.mid (95/908), assigned song_id=94
#   [info] pick_melody_part: selected by stats: part_name='jeffrey mutya', avg_pitch=60.1, n_notes=475
#   Saved transposed: ../data/processed/transposed_midis/transposed_Best_ove.mid
# Processing Blaueaug.mid (96/908), assigned song_id=95
#   [info] pick_melody_part: selected by stats: part_name='blaueaug', avg_pitch=63.1, n_notes=1513
#   Saved transposed: ../data/processed/transposed_midis/transposed_Blaueaug.mid
# Processing BuffSold.mid (97/908), assigned song_id=96
#   [info] pick_melody_part: selected by stats: part_name='organ', avg_pitch=74.4, n_notes=484
#   Saved transposed: ../data/processed/transposed_midis/transposed_BuffSold.mid
# Processing CHUMBAWAMBA.Tubthumping.mid (98/908), assigned song_id=97
#   [info] pick_melody_part: selected by name heuristic: part_name='tubthumpi', avg_pitch=65.8, n_notes=1042
#   Saved transposed: ../data/processed/transposed_midis/transposed_CHUMBAWAMBA.Tubthumping.mid
# Processing Christina Aguilera Genie in a Bottle.mid (99/908), assigned song_id=98
#   [info] pick_melody_part: selected by stats: part_name='sequenced by mario rol', avg_pitch=85.0, n_notes=731
#   Saved transposed: ../data/processed/transposed_midis/transposed_Christina Aguilera Genie in a Bottle.mid
# Processing Cosmic_Gate___The_Truth__John_20061205134903.mid (100/908), assigned song_id=99
#   [info] pick_melody_part: selected by name heuristic: part_name='melody', avg_pitch=70.5, n_notes=92
#   Saved transposed: ../data/processed/transposed_midis/transposed_Cosmic_Gate___The_Truth__John_20061205134903.mid
# Processing D _ Feelslikeheaven.mid (101/908), assigned song_id=100
#   [info] pick_melody_part: selected by stats: part_name='percussion', avg_pitch=60.7, n_notes=388
#   Saved transposed: ../data/processed/transposed_midis/transposed_D _ Feelslikeheaven.mid
# Processing D _ Moreandmore.mid (102/908), assigned song_id=101
#   [info] pick_melody_part: selected by stats: part_name='main synth', avg_pitch=71.6, n_notes=640
#   Saved transposed: ../data/processed/transposed_midis/transposed_D _ Moreandmore.mid
# Processing D _ Pleasedontgo.mid (103/908), assigned song_id=102
#   [info] pick_melody_part: selected by name heuristic: part_name='sampler', avg_pitch=89.8, n_notes=17
#   Saved transposed: ../data/processed/transposed_midis/transposed_D _ Pleasedontgo.mid
#   Skipping D _ Pleasedontgo.mid: too few notes (17)
# Processing DONTSTOP.mid (104/908), assigned song_id=103
#   [info] pick_melody_part: selected by name heuristic: part_name='dontstop', avg_pitch=70.3, n_notes=1815
#   Saved transposed: ../data/processed/transposed_midis/transposed_DONTSTOP.mid
# Processing D_Code Feat. Emma _ My Direction (Styles & Breeze Remix).mid (105/908), assigned song_id=104
#   [info] pick_melody_part: selected by stats: part_name='midi 04', avg_pitch=67.9, n_notes=72
#   Saved transposed: ../data/processed/transposed_midis/transposed_D_Code Feat. Emma _ My Direction (Styles & Breeze Remix).mid
# Processing Dido_White_flag.mid (106/908), assigned song_id=105
#   [info] pick_melody_part: selected by stats: part_name='white flag', avg_pitch=68.8, n_notes=1052
#   Saved transposed: ../data/processed/transposed_midis/transposed_Dido_White_flag.mid
# Processing Don't_Take_Away_In_The_Music.mid (107/908), assigned song_id=106
#   [info] pick_melody_part: selected by name heuristic: part_name='7685dont', avg_pitch=63.4, n_notes=1463
#   Saved transposed: ../data/processed/transposed_midis/transposed_Don't_Take_Away_In_The_Music.mid
# Processing Dontleav.mid (108/908), assigned song_id=107
#   [info] pick_melody_part: selected by stats: part_name='dontleav', avg_pitch=63.8, n_notes=1137
#   Saved transposed: ../data/processed/transposed_midis/transposed_Dontleav.mid
# Processing Get_Down_On_It.mid (109/908), assigned song_id=108
#   [info] pick_melody_part: selected by name heuristic: part_name='melody', avg_pitch=70.7, n_notes=673
#   Saved transposed: ../data/processed/transposed_midis/transposed_Get_Down_On_It.mid
# Processing Gorillaz_Kids_with_guns.mid (110/908), assigned song_id=109
#   [info] pick_melody_part: selected by name heuristic: part_name='voice', avg_pitch=56.3, n_notes=284
#   Saved transposed: ../data/processed/transposed_midis/transposed_Gorillaz_Kids_with_guns.mid
# Processing Happy_Nation_1.mid (111/908), assigned song_id=110
#   [info] pick_melody_part: selected by name heuristic: part_name='solo vox', avg_pitch=89.7, n_notes=49
#   Saved transposed: ../data/processed/transposed_midis/transposed_Happy_Nation_1.mid
# Processing Horny 98.mid (112/908), assigned song_id=111
#   [info] pick_melody_part: selected by stats: part_name='horny98', avg_pitch=68.0, n_notes=881
#   Saved transposed: ../data/processed/transposed_midis/transposed_Horny 98.mid
# Processing I Robot.mid (113/908), assigned song_id=112
#   [info] pick_melody_part: selected by name heuristic: part_name='bass lead', avg_pitch=42.2, n_notes=1064
#   Saved transposed: ../data/processed/transposed_midis/transposed_I Robot.mid
# Processing I Want You Back.mid (114/908), assigned song_id=113
#   [info] pick_melody_part: selected by stats: part_name='tenor saxophone', avg_pitch=69.2, n_notes=353
#   Saved transposed: ../data/processed/transposed_midis/transposed_I Want You Back.mid
# Processing It's Raining Men Pm L.mid (115/908), assigned song_id=114
#   [info] pick_melody_part: selected by stats: part_name='it's raining men', avg_pitch=64.6, n_notes=1698
#   Saved transposed: ../data/processed/transposed_midis/transposed_It's Raining Men Pm L.mid
# Processing J'ai Peur En Réparation.mid (116/908), assigned song_id=115
#   [info] pick_melody_part: selected by stats: part_name='sampler', avg_pitch=79.7, n_notes=1290
#   Saved transposed: ../data/processed/transposed_midis/transposed_J'ai Peur En Réparation.mid
# Processing JACKSON.Smooth criminal K.mid (117/908), assigned song_id=116
#   [info] pick_melody_part: selected by stats: part_name='vibraphone', avg_pitch=57.0, n_notes=693
#   Saved transposed: ../data/processed/transposed_midis/transposed_JACKSON.Smooth criminal K.mid
# Processing Jammin L.mid (118/908), assigned song_id=117
#   [info] pick_melody_part: selected by stats: part_name='piano', avg_pitch=64.8, n_notes=732
#   Saved transposed: ../data/processed/transposed_midis/transposed_Jammin L.mid
# Processing Jane_Funk.mid (119/908), assigned song_id=118
#   [info] pick_melody_part: selected by stats: part_name='choir aahs', avg_pitch=76.7, n_notes=102
#   Saved transposed: ../data/processed/transposed_midis/transposed_Jane_Funk.mid
# Processing Join_Me_3.mid (120/908), assigned song_id=119
#   [info] pick_melody_part: selected by stats: part_name='dj !gor (dj.igor@tut.by)', avg_pitch=60.1, n_notes=366
#   Saved transposed: ../data/processed/transposed_midis/transposed_Join_Me_3.mid
# Processing JustinTimberlake_Rock_your_body.mid (121/908), assigned song_id=120
#   [info] pick_melody_part: selected by stats: part_name='electric bass', avg_pitch=65.5, n_notes=994
#   Saved transposed: ../data/processed/transposed_midis/transposed_JustinTimberlake_Rock_your_body.mid
# Processing Keeponmo.mid (122/908), assigned song_id=121
#   [info] pick_melody_part: selected by stats: part_name='keeponmo', avg_pitch=61.6, n_notes=1297
#   Saved transposed: ../data/processed/transposed_midis/transposed_Keeponmo.mid
# Processing L._Di_Lernia___Maccarone_(Macarena)[1].mid (123/908), assigned song_id=122
#   [info] pick_melody_part: selected by name heuristic: part_name='melody', avg_pitch=57.1, n_notes=782
#   Saved transposed: ../data/processed/transposed_midis/transposed_L._Di_Lernia___Maccarone_(Macarena)[1].mid
# Processing Lara Fabian _ I Will Love Again.mid (124/908), assigned song_id=123
#   [info] pick_melody_part: selected by stats: part_name='piccolo', avg_pitch=68.7, n_notes=1410
#   Saved transposed: ../data/processed/transposed_midis/transposed_Lara Fabian _ I Will Love Again.mid
# Processing Living on Video.mid (125/908), assigned song_id=124
#   [info] pick_melody_part: selected by stats: part_name='sci-fi', avg_pitch=69.3, n_notes=512
#   Saved transposed: ../data/processed/transposed_midis/transposed_Living on Video.mid
# Processing Love Comes Quickly.mid (126/908), assigned song_id=125
#   [info] pick_melody_part: selected by name heuristic: part_name='melody', avg_pitch=70.5, n_notes=343
#   Saved transposed: ../data/processed/transposed_midis/transposed_Love Comes Quickly.mid
# Processing Luis Aguile Dile.mid (127/908), assigned song_id=126
#   [info] pick_melody_part: selected by stats: part_name='tell him - exiters', avg_pitch=80.2, n_notes=330
#   Saved transposed: ../data/processed/transposed_midis/transposed_Luis Aguile Dile.mid
# Processing M. Carey Without You.mid (128/908), assigned song_id=127
#   [info] pick_melody_part: selected by name heuristic: part_name='melody', avg_pitch=72.8, n_notes=336
#   Saved transposed: ../data/processed/transposed_midis/transposed_M. Carey Without You.mid
# Processing Namegame.mid (129/908), assigned song_id=128
#   [info] pick_melody_part: selected by stats: part_name='the name of the game            ;benny andersson / bjorn ulvaeus / stig anderson', avg_pitch=61.7, n_notes=1653
#   Saved transposed: ../data/processed/transposed_midis/transposed_Namegame.mid
# Processing Never Can Say Goodbye.mid (130/908), assigned song_id=129
#   [info] pick_melody_part: selected by name heuristic: part_name='melody', avg_pitch=69.4, n_notes=555
#   Saved transposed: ../data/processed/transposed_midis/transposed_Never Can Say Goodbye.mid
# Processing Outstanding.mid (131/908), assigned song_id=130
#   [info] pick_melody_part: selected by name heuristic: part_name='lead', avg_pitch=70.4, n_notes=557
#   Saved transposed: ../data/processed/transposed_midis/transposed_Outstanding.mid
# Processing Peggy_Sue_1.mid (132/908), assigned song_id=131
#   [info] pick_melody_part: selected by name heuristic: part_name='melody', avg_pitch=56.4, n_notes=265
#   Saved transposed: ../data/processed/transposed_midis/transposed_Peggy_Sue_1.mid
# Processing Play_That_Funky_Music.mid (133/908), assigned song_id=132
#   [info] pick_melody_part: selected by name heuristic: part_name='melody', avg_pitch=63.0, n_notes=553
#   Saved transposed: ../data/processed/transposed_midis/transposed_Play_That_Funky_Music.mid
# Processing Poison Arrow.mid (134/908), assigned song_id=133
#   [info] pick_melody_part: selected by name heuristic: part_name='melody & lyric', avg_pitch=61.2, n_notes=343
#   Saved transposed: ../data/processed/transposed_midis/transposed_Poison Arrow.mid
# Processing Poly 2193.mid (135/908), assigned song_id=134
#   [info] pick_melody_part: selected by stats: part_name='fretless bass', avg_pitch=70.4, n_notes=217
#   Saved transposed: ../data/processed/transposed_midis/transposed_Poly 2193.mid
# Processing Poly 2225.mid (136/908), assigned song_id=135
#   [info] pick_melody_part: selected by name heuristic: part_name='electric bass', avg_pitch=63.5, n_notes=96
#   Saved transposed: ../data/processed/transposed_midis/transposed_Poly 2225.mid
# Processing Power_Of_American_Natives.mid (137/908), assigned song_id=136
#   [info] pick_melody_part: selected by stats: part_name='bottleblow', avg_pitch=69.4, n_notes=135
#   Saved transposed: ../data/processed/transposed_midis/transposed_Power_Of_American_Natives.mid
# Processing Pure_Energy.mid (138/908), assigned song_id=137
#   [info] pick_melody_part: selected by stats: part_name='distortion', avg_pitch=67.3, n_notes=500
#   Saved transposed: ../data/processed/transposed_midis/transposed_Pure_Energy.mid
# Processing Question.mid (139/908), assigned song_id=138
#   [info] pick_melody_part: selected by stats: part_name='question', avg_pitch=64.1, n_notes=1069
#   Saved transposed: ../data/processed/transposed_midis/transposed_Question.mid
# Processing Red Hot Chili Peppers _ Can't Stop.mid (140/908), assigned song_id=139
#   [info] pick_melody_part: selected by name heuristic: part_name='solo guitar', avg_pitch=69.3, n_notes=143
#   Saved transposed: ../data/processed/transposed_midis/transposed_Red Hot Chili Peppers _ Can't Stop.mid
# Processing Ring My Bell.mid (141/908), assigned song_id=140
#   [info] pick_melody_part: selected by stats: part_name='', avg_pitch=75.3, n_notes=990
#   Saved transposed: ../data/processed/transposed_midis/transposed_Ring My Bell.mid
# Processing Roses are Red.mid (142/908), assigned song_id=141
#   [info] pick_melody_part: selected by stats: part_name='saw wawe', avg_pitch=67.0, n_notes=648
#   Saved transposed: ../data/processed/transposed_midis/transposed_Roses are Red.mid
# Processing Runtoyou.mid (143/908), assigned song_id=142
#   [info] pick_melody_part: selected by name heuristic: part_name='runtoyou', avg_pitch=57.9, n_notes=1218
#   Saved transposed: ../data/processed/transposed_midis/transposed_Runtoyou.mid
# Processing Sei Un Mito 2.mid (144/908), assigned song_id=143
#   [info] pick_melody_part: selected by stats: part_name='vibraphone', avg_pitch=68.3, n_notes=603
#   Saved transposed: ../data/processed/transposed_midis/transposed_Sei Un Mito 2.mid
# Processing Sleeping Satellites.mid (145/908), assigned song_id=144
#   [info] pick_melody_part: selected by stats: part_name='sleeping satellites', avg_pitch=62.5, n_notes=1165
#   Saved transposed: ../data/processed/transposed_midis/transposed_Sleeping Satellites.mid
# Processing Smoothcr.mid (146/908), assigned song_id=145
#   [info] pick_melody_part: selected by stats: part_name='smoothcr', avg_pitch=60.0, n_notes=760
#   Saved transposed: ../data/processed/transposed_midis/transposed_Smoothcr.mid
# Processing Supermans Dead.mid (147/908), assigned song_id=146
#   [info] pick_melody_part: selected by name heuristic: part_name='vocals', avg_pitch=61.5, n_notes=510
#   Saved transposed: ../data/processed/transposed_midis/transposed_Supermans Dead.mid
# Processing THE CLASH.Rock the casbah.mid (148/908), assigned song_id=147
#   [info] pick_melody_part: selected by name heuristic: part_name='====================', avg_pitch=59.7, n_notes=1150
#   Saved transposed: ../data/processed/transposed_midis/transposed_THE CLASH.Rock the casbah.mid
# Processing THE COMETS.Scooby Dooby Boy.mid (149/908), assigned song_id=148
#   [info] pick_melody_part: selected by stats: part_name='scobidoobi', avg_pitch=69.2, n_notes=1221
#   Saved transposed: ../data/processed/transposed_midis/transposed_THE COMETS.Scooby Dooby Boy.mid
# Processing Tainted_Love.mid (150/908), assigned song_id=149
#   [info] pick_melody_part: selected by stats: part_name='electric organ', avg_pitch=70.3, n_notes=380
#   Saved transposed: ../data/processed/transposed_midis/transposed_Tainted_Love.mid
# Processing Thisgood.mid (151/908), assigned song_id=150
#   [info] pick_melody_part: selected by stats: part_name='thisgood', avg_pitch=64.2, n_notes=1209
#   Saved transposed: ../data/processed/transposed_midis/transposed_Thisgood.mid
# Processing Verrueck.mid (152/908), assigned song_id=151
#   [info] pick_melody_part: selected by stats: part_name='verrueck', avg_pitch=64.1, n_notes=1215
#   Saved transposed: ../data/processed/transposed_midis/transposed_Verrueck.mid
# Processing Voyage_Voyage_2.mid (153/908), assigned song_id=152
#   [info] pick_melody_part: selected by name heuristic: part_name='voyage v.', avg_pitch=58.6, n_notes=1169
#   Saved transposed: ../data/processed/transposed_midis/transposed_Voyage_Voyage_2.mid
# Processing Wannabe 2 32.mid (154/908), assigned song_id=153
#   [info] pick_melody_part: selected by stats: part_name='clarinet', avg_pitch=65.3, n_notes=326
#   Saved transposed: ../data/processed/transposed_midis/transposed_Wannabe 2 32.mid
# Processing West End Girls.mid (155/908), assigned song_id=154
#   [info] pick_melody_part: selected by name heuristic: part_name='trumpet', avg_pitch=73.2, n_notes=113
#   Saved transposed: ../data/processed/transposed_midis/transposed_West End Girls.mid
# Processing When All is Said and Done.mid (156/908), assigned song_id=155
#   [info] pick_melody_part: selected by name heuristic: part_name='frida', avg_pitch=65.7, n_notes=323
#   Saved transposed: ../data/processed/transposed_midis/transposed_When All is Said and Done.mid
# Processing Whenwear.mid (157/908), assigned song_id=156
#   [info] pick_melody_part: selected by name heuristic: part_name='whenwear', avg_pitch=64.5, n_notes=1262
#   Saved transposed: ../data/processed/transposed_midis/transposed_Whenwear.mid
# Processing You_Got_It_(The_Right_Stuff)_2.mid (158/908), assigned song_id=157
#   [info] pick_melody_part: selected by name heuristic: part_name='0035stuf', avg_pitch=68.2, n_notes=624
#   Saved transposed: ../data/processed/transposed_midis/transposed_You_Got_It_(The_Right_Stuff)_2.mid
# Processing backstreetthatway.mid (159/908), assigned song_id=158
#   [info] pick_melody_part: selected by stats: part_name='sampler', avg_pitch=71.4, n_notes=258
#   Saved transposed: ../data/processed/transposed_midis/transposed_backstreetthatway.mid
# Processing black_eyed_peas_i_gotta_feeling.mid (160/908), assigned song_id=159
#   [info] pick_melody_part: selected by name heuristic: part_name='midi', avg_pitch=62.4, n_notes=1188
#   Saved transposed: ../data/processed/transposed_midis/transposed_black_eyed_peas_i_gotta_feeling.mid
# Processing breath3.mid (161/908), assigned song_id=160
#   [info] pick_melody_part: selected by stats: part_name='ch  9', avg_pitch=85.6, n_notes=246
#   Saved transposed: ../data/processed/transposed_midis/transposed_breath3.mid
# Processing cascada_miracle.mid (162/908), assigned song_id=161
#   [info] pick_melody_part: selected by stats: part_name='miracle', avg_pitch=68.1, n_notes=778
#   Saved transposed: ../data/processed/transposed_midis/transposed_cascada_miracle.mid
# Processing cascada_pyromania.mid (163/908), assigned song_id=162
#   [info] pick_melody_part: selected by stats: part_name='dispositivo gm 14', avg_pitch=71.1, n_notes=1073
#   Saved transposed: ../data/processed/transposed_midis/transposed_cascada_pyromania.mid
# Processing cheryl_cole_3_words_feat_william.mid (164/908), assigned song_id=163
#   [info] pick_melody_part: selected by stats: part_name='3 words', avg_pitch=67.2, n_notes=1740
#   Saved transposed: ../data/processed/transposed_midis/transposed_cheryl_cole_3_words_feat_william.mid
# Processing chris_isaak_baby_did_a_bad_thing.mid (165/908), assigned song_id=164
#   [info] pick_melody_part: selected by stats: part_name='fretless bass', avg_pitch=48.5, n_notes=1379
#   Saved transposed: ../data/processed/transposed_midis/transposed_chris_isaak_baby_did_a_bad_thing.mid
# Processing concious.mid (166/908), assigned song_id=165
#   [info] pick_melody_part: selected by name heuristic: part_name='trumpet    e6', avg_pitch=78.7, n_notes=38
#   Saved transposed: ../data/processed/transposed_midis/transposed_concious.mid
# Processing crazyonu.mid (167/908), assigned song_id=166
#   [info] pick_melody_part: selected by name heuristic: part_name='rhythm guitar', avg_pitch=59.0, n_notes=1280
#   Saved transposed: ../data/processed/transposed_midis/transposed_crazyonu.mid
# Processing dj_amid__universe__originals.mid (168/908), assigned song_id=167
#   [info] pick_melody_part: selected by name heuristic: part_name='melody (midi)', avg_pitch=69.7, n_notes=416
#   Saved transposed: ../data/processed/transposed_midis/transposed_dj_amid__universe__originals.mid
# Processing dj_sakin_&_friends__protect_your_mind__unknown.mid (169/908), assigned song_id=168
#   [info] pick_melody_part: selected by stats: part_name='sc88pro', avg_pitch=66.2, n_notes=916
#   Saved transposed: ../data/processed/transposed_midis/transposed_dj_sakin_&_friends__protect_your_mind__unknown.mid
# Processing don_omar_dile.mid (170/908), assigned song_id=169
#   [info] pick_melody_part: selected by name heuristic: part_name='lead 2', avg_pitch=59.3, n_notes=181
#   Saved transposed: ../data/processed/transposed_midis/transposed_don_omar_dile.mid
# Processing dothattome.mid (171/908), assigned song_id=170
#   [info] pick_melody_part: selected by stats: part_name='chorusedpiano', avg_pitch=62.7, n_notes=845
#   Saved transposed: ../data/processed/transposed_midis/transposed_dothattome.mid
# Processing duong_ve_don_coi.mid (172/908), assigned song_id=171
#   [info] pick_melody_part: selected by stats: part_name='percussion', avg_pitch=68.4, n_notes=1130
#   Saved transposed: ../data/processed/transposed_midis/transposed_duong_ve_don_coi.mid
# Processing footlose.mid (173/908), assigned song_id=172
#   [info] pick_melody_part: selected by stats: part_name='sampler', avg_pitch=73.7, n_notes=402
#   Saved transposed: ../data/processed/transposed_midis/transposed_footlose.mid
# Processing house03.mid (174/908), assigned song_id=173
#   [info] pick_melody_part: selected by stats: part_name='whistle', avg_pitch=93.5, n_notes=848
#   Saved transposed: ../data/processed/transposed_midis/transposed_house03.mid
# Processing house_of_the_rising_sun3_F95.mid (175/908), assigned song_id=174
#   [info] pick_melody_part: selected by stats: part_name='elecguitar', avg_pitch=81.9, n_notes=943
#   Saved transposed: ../data/processed/transposed_midis/transposed_house_of_the_rising_sun3_F95.mid
# Processing ineedsomebody_bardot.mid (176/908), assigned song_id=175
#   [info] pick_melody_part: selected by stats: part_name='sampler', avg_pitch=67.1, n_notes=226
#   Saved transposed: ../data/processed/transposed_midis/transposed_ineedsomebody_bardot.mid
# Processing katy_perry_if_you_can_afford_me.mid (177/908), assigned song_id=176
#   [info] pick_melody_part: selected by stats: part_name='electric guitar', avg_pitch=62.8, n_notes=680
#   Saved transposed: ../data/processed/transposed_midis/transposed_katy_perry_if_you_can_afford_me.mid
# Processing lady_gaga_paper_gangsta.mid (178/908), assigned song_id=177
#   [info] pick_melody_part: selected by stats: part_name='paper gangster', avg_pitch=66.8, n_notes=1126
#   Saved transposed: ../data/processed/transposed_midis/transposed_lady_gaga_paper_gangsta.mid
# Processing martin_solveig_everybody.mid (179/908), assigned song_id=178
#   [info] pick_melody_part: selected by stats: part_name='electric bass', avg_pitch=57.8, n_notes=806
#   Saved transposed: ../data/processed/transposed_midis/transposed_martin_solveig_everybody.mid
# Processing ram_jam_black_betty.mid (180/908), assigned song_id=179
#   [info] pick_melody_part: selected by stats: part_name='electric bass', avg_pitch=37.6, n_notes=663
#   Saved transposed: ../data/processed/transposed_midis/transposed_ram_jam_black_betty.mid
# Processing scooter__megamix1__vlad.mid (181/908), assigned song_id=180
#   [info] pick_melody_part: selected by stats: part_name='untitled', avg_pitch=65.9, n_notes=1311
#   Saved transposed: ../data/processed/transposed_midis/transposed_scooter__megamix1__vlad.mid
# Processing staytog.mid (182/908), assigned song_id=181
#   [info] pick_melody_part: selected by stats: part_name='organ', avg_pitch=77.7, n_notes=204
#   Saved transposed: ../data/processed/transposed_midis/transposed_staytog.mid
# Processing sugababes_denial.mid (183/908), assigned song_id=182
#   [info] pick_melody_part: selected by stats: part_name='denial', avg_pitch=64.4, n_notes=201
#   Saved transposed: ../data/processed/transposed_midis/transposed_sugababes_denial.mid
# Processing tacabro_tacata.mid (184/908), assigned song_id=183
#   [info] pick_melody_part: selected by name heuristic: part_name='lead 8', avg_pitch=75.0, n_notes=152
#   Saved transposed: ../data/processed/transposed_midis/transposed_tacabro_tacata.mid
# Processing taio_cruz_break_your_heart.mid (185/908), assigned song_id=184
#   [info] pick_melody_part: selected by name heuristic: part_name='chant', avg_pitch=73.8, n_notes=473
#   Saved transposed: ../data/processed/transposed_midis/transposed_taio_cruz_break_your_heart.mid
# Processing toy_box___best_friend.mid (186/908), assigned song_id=185
#   [info] pick_melody_part: selected by stats: part_name='sequenced for toplist team', avg_pitch=88.3, n_notes=1197
#   Saved transposed: ../data/processed/transposed_midis/transposed_toy_box___best_friend.mid
# Processing toy_box___tarzan_and_jane.mid (187/908), assigned song_id=186
#   [info] pick_melody_part: selected by stats: part_name='stringinstrument', avg_pitch=87.0, n_notes=704
#   Saved transposed: ../data/processed/transposed_midis/transposed_toy_box___tarzan_and_jane.mid
# Processing 08_Dis_Dread_Is_Sure.mid (188/908), assigned song_id=187
#   [info] pick_melody_part: selected by stats: part_name='piano', avg_pitch=75.2, n_notes=288
#   Saved transposed: ../data/processed/transposed_midis/transposed_08_Dis_Dread_Is_Sure.mid
# ...
# Processing Maroon5_She_will_be_loved.mid (847/908), assigned song_id=846
#   [info] pick_melody_part: selected by stats: part_name='vocals', avg_pitch=63.4, n_notes=515
#   Saved transposed: ../data/processed/transposed_midis/transposed_Maroon5_She_will_be_loved.mid
# Processing Moon_Over_Bourbon_Street_2.mid (848/908), assigned song_id=847
#   [info] pick_melody_part: selected by name heuristic: part_name='melody', avg_pitch=70.1, n_notes=326
#   Saved transposed: ../data/processed/transposed_midis/transposed_Moon_Over_Bourbon_Street_2.mid
# Processing Namegame.mid (849/908), assigned song_id=848
#   [info] pick_melody_part: selected by stats: part_name='the name of the game            ;benny andersson / bjorn ulvaeus / stig anderson', avg_pitch=61.7, n_notes=1653
#   Saved transposed: ../data/processed/transposed_midis/transposed_Namegame.mid
# Processing Non Finira.mid (850/908), assigned song_id=849
#   [info] pick_melody_part: selected by name heuristic: part_name='fretless bass', avg_pitch=67.4, n_notes=902
#   Saved transposed: ../data/processed/transposed_midis/transposed_Non Finira.mid
# Processing Nurmitdi.mid (851/908), assigned song_id=850
#   [info] pick_melody_part: selected by stats: part_name='nurmitdi', avg_pitch=63.1, n_notes=1174
#   Saved transposed: ../data/processed/transposed_midis/transposed_Nurmitdi.mid
# Processing Peggy_Sue_1.mid (852/908), assigned song_id=851
#   [info] pick_melody_part: selected by name heuristic: part_name='melody', avg_pitch=56.4, n_notes=265
#   Saved transposed: ../data/processed/transposed_midis/transposed_Peggy_Sue_1.mid
# Processing Play_That_Funky_Music.mid (853/908), assigned song_id=852
#   [info] pick_melody_part: selected by name heuristic: part_name='melody', avg_pitch=63.0, n_notes=553
#   Saved transposed: ../data/processed/transposed_midis/transposed_Play_That_Funky_Music.mid
# Processing Poison Arrow.mid (854/908), assigned song_id=853
#   [info] pick_melody_part: selected by name heuristic: part_name='melody & lyric', avg_pitch=61.2, n_notes=343
#   Saved transposed: ../data/processed/transposed_midis/transposed_Poison Arrow.mid
# Processing Poly 2364.mid (855/908), assigned song_id=854
#   [info] pick_melody_part: selected by stats: part_name='untitled', avg_pitch=63.6, n_notes=179
#   Saved transposed: ../data/processed/transposed_midis/transposed_Poly 2364.mid
# Processing Precious_And_Few.mid (856/908), assigned song_id=855
#   [info] pick_melody_part: selected by stats: part_name='a.piano 1', avg_pitch=73.0, n_notes=406
#   Saved transposed: ../data/processed/transposed_midis/transposed_Precious_And_Few.mid
# Processing Rio Negro E Solimoes _ To Por Ai.mid (857/908), assigned song_id=856
#   [info] pick_melody_part: selected by stats: part_name='to por ai', avg_pitch=58.5, n_notes=2301
#   Saved transposed: ../data/processed/transposed_midis/transposed_Rio Negro E Solimoes _ To Por Ai.mid
# Processing Rock_'N_Roll_Is_King.mid (858/908), assigned song_id=857
#   [info] pick_melody_part: selected by name heuristic: part_name='melody', avg_pitch=74.0, n_notes=388
#   Saved transposed: ../data/processed/transposed_midis/transposed_Rock_'N_Roll_Is_King.mid
# Processing Roses are Red.mid (859/908), assigned song_id=858
#   [info] pick_melody_part: selected by stats: part_name='saw wawe', avg_pitch=67.0, n_notes=648
#   Saved transposed: ../data/processed/transposed_midis/transposed_Roses are Red.mid
# Processing Runtoyou.mid (860/908), assigned song_id=859
#   [info] pick_melody_part: selected by name heuristic: part_name='runtoyou', avg_pitch=57.9, n_notes=1218
#   Saved transposed: ../data/processed/transposed_midis/transposed_Runtoyou.mid
# Processing Sade by Your Side.mid (861/908), assigned song_id=860
#   [info] pick_melody_part: selected by name heuristic: part_name='pan flute', avg_pitch=73.8, n_notes=259
#   Saved transposed: ../data/processed/transposed_midis/transposed_Sade by Your Side.mid
# Processing Searcher.mid (862/908), assigned song_id=861
#   [info] pick_melody_part: selected by stats: part_name='searcher', avg_pitch=68.6, n_notes=1563
#   Saved transposed: ../data/processed/transposed_midis/transposed_Searcher.mid
# Processing Septmc.mid (863/908), assigned song_id=862
#   [info] pick_melody_part: selected by stats: part_name='rock organ', avg_pitch=70.3, n_notes=339
#   Saved transposed: ../data/processed/transposed_midis/transposed_Septmc.mid
# Processing SimplePlan_Im_just_a_kid.mid (864/908), assigned song_id=863
#   [info] pick_melody_part: selected by stats: part_name='tabit midi - track 2', avg_pitch=59.0, n_notes=644
#   Saved transposed: ../data/processed/transposed_midis/transposed_SimplePlan_Im_just_a_kid.mid
# Processing SisterGoldenHair.mid (865/908), assigned song_id=864
#   [info] pick_melody_part: selected by stats: part_name='untitled', avg_pitch=60.9, n_notes=1171
#   Saved transposed: ../data/processed/transposed_midis/transposed_SisterGoldenHair.mid
# Processing Sleeping Satellites.mid (866/908), assigned song_id=865
#   [info] pick_melody_part: selected by stats: part_name='sleeping satellites', avg_pitch=62.5, n_notes=1165
#   Saved transposed: ../data/processed/transposed_midis/transposed_Sleeping Satellites.mid
# Processing Smoothcr.mid (867/908), assigned song_id=866
#   [info] pick_melody_part: selected by stats: part_name='smoothcr', avg_pitch=60.0, n_notes=760
#   Saved transposed: ../data/processed/transposed_midis/transposed_Smoothcr.mid
# Processing Songforg.mid (868/908), assigned song_id=867
#   [info] pick_melody_part: selected by stats: part_name='percussion', avg_pitch=67.3, n_notes=639
#   Saved transposed: ../data/processed/transposed_midis/transposed_Songforg.mid
# Processing Stopinthenameoflove L.mid (869/908), assigned song_id=868
#   [info] pick_melody_part: selected by stats: part_name='untitled', avg_pitch=59.3, n_notes=604
#   Saved transposed: ../data/processed/transposed_midis/transposed_Stopinthenameoflove L.mid
# Processing Stumblin L.mid (870/908), assigned song_id=869
#   [info] pick_melody_part: selected by stats: part_name='electric piano', avg_pitch=65.2, n_notes=1255
#   Saved transposed: ../data/processed/transposed_midis/transposed_Stumblin L.mid
# Processing Sure Know Something.mid (871/908), assigned song_id=870
#   [info] pick_melody_part: selected by stats: part_name='electric bass', avg_pitch=58.9, n_notes=1009
#   Saved transposed: ../data/processed/transposed_midis/transposed_Sure Know Something.mid
# Processing Sweet Sixteen(Bbking) L.mid (872/908), assigned song_id=871
#   [info] pick_melody_part: selected by name heuristic: part_name='sweet sixteen                   ;b.b.', avg_pitch=64.7, n_notes=811
#   Saved transposed: ../data/processed/transposed_midis/transposed_Sweet Sixteen(Bbking) L.mid
# Processing Tainted_Love.mid (873/908), assigned song_id=872
#   [info] pick_melody_part: selected by stats: part_name='electric organ', avg_pitch=70.3, n_notes=380
#   Saved transposed: ../data/processed/transposed_midis/transposed_Tainted_Love.mid
# Processing Tears Of A Clown.mid (874/908), assigned song_id=873
#   [info] pick_melody_part: selected by name heuristic: part_name='tears of a clown', avg_pitch=66.2, n_notes=819
#   Saved transposed: ../data/processed/transposed_midis/transposed_Tears Of A Clown.mid
# Processing V. Carlton a Thousand Miles.mid (875/908), assigned song_id=874
#   [info] pick_melody_part: selected by stats: part_name='piano', avg_pitch=66.1, n_notes=790
#   Saved transposed: ../data/processed/transposed_midis/transposed_V. Carlton a Thousand Miles.mid
# Processing Vampire.mid (876/908), assigned song_id=875
#   [info] pick_melody_part: selected by name heuristic: part_name='fretless bass', avg_pitch=46.4, n_notes=561
#   Saved transposed: ../data/processed/transposed_midis/transposed_Vampire.mid
# Processing We've Only Just Begun.mid (877/908), assigned song_id=876
#   [info] pick_melody_part: selected by name heuristic: part_name='we've only just begun           ;paul williams / roger nichols', avg_pitch=65.1, n_notes=1028
#   Saved transposed: ../data/processed/transposed_midis/transposed_We've Only Just Begun.mid
# Processing Weird Al Yankovic.mid (878/908), assigned song_id=877
#   [info] pick_melody_part: selected by stats: part_name='guitar 2', avg_pitch=53.6, n_notes=452
#   Saved transposed: ../data/processed/transposed_midis/transposed_Weird Al Yankovic.mid
# Processing West End Girls.mid (879/908), assigned song_id=878
#   [info] pick_melody_part: selected by name heuristic: part_name='trumpet', avg_pitch=73.2, n_notes=113
#   Saved transposed: ../data/processed/transposed_midis/transposed_West End Girls.mid
# Processing When All is Said and Done.mid (880/908), assigned song_id=879
#   [info] pick_melody_part: selected by name heuristic: part_name='frida', avg_pitch=65.7, n_notes=323
#   Saved transposed: ../data/processed/transposed_midis/transposed_When All is Said and Done.mid
# Processing Working_Man.mid (881/908), assigned song_id=880
#   [info] pick_melody_part: selected by stats: part_name='guitar', avg_pitch=54.9, n_notes=438
#   Saved transposed: ../data/processed/transposed_midis/transposed_Working_Man.mid
# Processing You'll Never Walk Alone 2.mid (882/908), assigned song_id=881
#   [info] pick_melody_part: selected by stats: part_name='alto saxophone', avg_pitch=70.2, n_notes=102
#   Saved transposed: ../data/processed/transposed_midis/transposed_You'll Never Walk Alone 2.mid
# Processing backstreetthatway.mid (883/908), assigned song_id=882
#   [info] pick_melody_part: selected by stats: part_name='sampler', avg_pitch=71.4, n_notes=258
#   Saved transposed: ../data/processed/transposed_midis/transposed_backstreetthatway.mid
# Processing california_dreamin5_F120.mid (884/908), assigned song_id=883
#   [info] pick_melody_part: selected by name heuristic: part_name='flute', avg_pitch=74.3, n_notes=86
#   Saved transposed: ../data/processed/transposed_midis/transposed_california_dreamin5_F120.mid
# Processing catsndcradle.mid (885/908), assigned song_id=884
#   [info] pick_melody_part: selected by name heuristic: part_name='lead voc', avg_pitch=69.2, n_notes=516
#   Saved transposed: ../data/processed/transposed_midis/transposed_catsndcradle.mid
# Processing cheryl_cole_3_words_feat_william.mid (886/908), assigned song_id=885
#   [info] pick_melody_part: selected by stats: part_name='3 words', avg_pitch=67.2, n_notes=1740
#   Saved transposed: ../data/processed/transposed_midis/transposed_cheryl_cole_3_words_feat_william.mid
# Processing chris_isaak_baby_did_a_bad_thing.mid (887/908), assigned song_id=886
#   [info] pick_melody_part: selected by stats: part_name='fretless bass', avg_pitch=48.5, n_notes=1379
#   Saved transposed: ../data/processed/transposed_midis/transposed_chris_isaak_baby_did_a_bad_thing.mid
# Processing crazyonu.mid (888/908), assigned song_id=887
#   [info] pick_melody_part: selected by name heuristic: part_name='rhythm guitar', avg_pitch=59.0, n_notes=1280
#   Saved transposed: ../data/processed/transposed_midis/transposed_crazyonu.mid
# Processing experiencia.mid (889/908), assigned song_id=888
#   [info] pick_melody_part: selected by name heuristic: part_name='letras', avg_pitch=72.4, n_notes=513
#   Saved transposed: ../data/processed/transposed_midis/transposed_experiencia.mid
# Processing footlose.mid (890/908), assigned song_id=889
#   [info] pick_melody_part: selected by stats: part_name='sampler', avg_pitch=73.7, n_notes=402
#   Saved transposed: ../data/processed/transposed_midis/transposed_footlose.mid
# Processing gun.mid (891/908), assigned song_id=890
#   [info] pick_melody_part: selected by stats: part_name='gun', avg_pitch=41.3, n_notes=419
#   Saved transposed: ../data/processed/transposed_midis/transposed_gun.mid
# Processing heyjoe2.mid (892/908), assigned song_id=891
#   [info] pick_melody_part: selected by stats: part_name='o\d gtr', avg_pitch=62.1, n_notes=205
#   Saved transposed: ../data/processed/transposed_midis/transposed_heyjoe2.mid
# Processing heytonight.mid (893/908), assigned song_id=892
#   [info] pick_melody_part: selected by name heuristic: part_name='rhythm guitar 2', avg_pitch=70.5, n_notes=614
#   Saved transposed: ../data/processed/transposed_midis/transposed_heytonight.mid
# Processing house03.mid (894/908), assigned song_id=893
#   [info] pick_melody_part: selected by stats: part_name='whistle', avg_pitch=93.5, n_notes=848
#   Saved transposed: ../data/processed/transposed_midis/transposed_house03.mid
# Processing i_can_see_clearly_now.mid (895/908), assigned song_id=894
#   [info] pick_melody_part: selected by name heuristic: part_name='piano solo', avg_pitch=86.5, n_notes=381
#   Saved transposed: ../data/processed/transposed_midis/transposed_i_can_see_clearly_now.mid
# Processing iris3.mid (896/908), assigned song_id=895
#   [info] pick_melody_part: selected by stats: part_name='written by the goo goo dolls', avg_pitch=63.7, n_notes=564
#   Saved transposed: ../data/processed/transposed_midis/transposed_iris3.mid
# Processing katy_perry_if_you_can_afford_me.mid (897/908), assigned song_id=896
#   [info] pick_melody_part: selected by stats: part_name='electric guitar', avg_pitch=62.8, n_notes=680
#   Saved transposed: ../data/processed/transposed_midis/transposed_katy_perry_if_you_can_afford_me.mid
# Processing kelly_clarkson_beautiful_disaster.mid (898/908), assigned song_id=897
#   [info] pick_melody_part: selected by stats: part_name='pad', avg_pitch=65.7, n_notes=2106
#   Saved transposed: ../data/processed/transposed_midis/transposed_kelly_clarkson_beautiful_disaster.mid
# Processing kid_rock_all_summer_long.mid (899/908), assigned song_id=898
#   [info] pick_melody_part: selected by stats: part_name='untitled', avg_pitch=62.7, n_notes=1360
#   Saved transposed: ../data/processed/transposed_midis/transposed_kid_rock_all_summer_long.mid
# Processing knokheav2.mid (900/908), assigned song_id=899
#   [info] pick_melody_part: selected by stats: part_name='piano', avg_pitch=71.2, n_notes=523
#   Saved transposed: ../data/processed/transposed_midis/transposed_knokheav2.mid
# Processing michael_buble_crazy_little_thing_called_love.mid (901/908), assigned song_id=900
#   [info] pick_melody_part: selected by name heuristic: part_name='crazy little thing called love', avg_pitch=63.0, n_notes=1101
#   Saved transposed: ../data/processed/transposed_midis/transposed_michael_buble_crazy_little_thing_called_love.mid
# Processing plush3.mid (902/908), assigned song_id=901
#   [info] pick_melody_part: selected by stats: part_name='guitar1', avg_pitch=58.2, n_notes=728
#   Saved transposed: ../data/processed/transposed_midis/transposed_plush3.mid
# Processing queens_of_the_stone_age_mosquitos_song.mid (903/908), assigned song_id=902
#   [info] pick_melody_part: selected by stats: part_name='"mosquito song" by queens of the stone age', avg_pitch=60.4, n_notes=1648
#   Saved transposed: ../data/processed/transposed_midis/transposed_queens_of_the_stone_age_mosquitos_song.mid
# Processing runaway.mid (904/908), assigned song_id=903
#   [info] pick_melody_part: selected by name heuristic: part_name='lead 8 (brass + lead)', avg_pitch=73.2, n_notes=165
#   Saved transposed: ../data/processed/transposed_midis/transposed_runaway.mid
# Processing sisosig.mid (905/908), assigned song_id=904
#   [info] pick_melody_part: selected by stats: part_name='untitled', avg_pitch=57.9, n_notes=364
#   Saved transposed: ../data/processed/transposed_midis/transposed_sisosig.mid
# Processing sugababes_denial.mid (906/908), assigned song_id=905
#   [info] pick_melody_part: selected by stats: part_name='denial', avg_pitch=64.4, n_notes=201
#   Saved transposed: ../data/processed/transposed_midis/transposed_sugababes_denial.mid
# Processing turnthepage.mid (907/908), assigned song_id=906
#   [info] pick_melody_part: selected by stats: part_name='alto', avg_pitch=63.9, n_notes=161
#   Saved transposed: ../data/processed/transposed_midis/transposed_turnthepage.mid
# Processing wishingyouwere.mid (908/908), assigned song_id=907
#   [info] pick_melody_part: selected by name heuristic: part_name='wishing you were', avg_pitch=68.4, n_notes=186
#   Saved transposed: ../data/processed/transposed_midis/transposed_wishingyouwere.mid
# Saved updated snippets to ../data/processed/snippets.npz
# Total snippets: 35878
# Total MIDI files represented: 895
